# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaSzAdr/CNN_cromossome/blob/master/TesteRede2_2_data_augmentation_Binaria_Base3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !pip install imutils

import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.optimizers import SGD
from keras.layers.core import Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score

from skimage import transform

import cv2
import csv
import imutils
import itertools
import matplotlib.pyplot as plt
import numpy as np
import os
# Out:
# Requirement already satisfied: imutils in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Using TensorFlow backend.

# %% [markdown]
# ## Funções

# %%
def converte(regiao):
   regiao = np.array(regiao).astype('float32')/255
   regiao = transform.resize(regiao, (120, 120, 3))
   regiao = np.expand_dims(regiao, axis=0)
   return regiao

# %% [markdown]
# ---
#
# *  [Keras, output of model predict_proba](https://stackoverflow.com/questions/41716380/keras-output-of-model-predict-proba/41729210#41729210)
# *  [keras: what is the difference between model.predict and model.predict_proba](https://stackoverflow.com/questions/40747679/keras-what-is-the-difference-between-model-predict-and-model-predict-proba)

# %%
def ler_images_teste(arquiteture):
  y_true = []
  y_predict = []
  prob = []
  
  images_test = os.listdir(test_path)
  local = 'drive/My Drive/Resultado/Segmentado/Resultado_Image/' + arquiteture
  if os.path.isdir(local) == False:
    os.mkdir(local)
  
  for img in images_test:
    # Pega cada imagem separadamente do folder de teste
    image = cv2.imread(test_path + '/' + img)
    f = open('drive/My Drive/Base_CNN/Binarizado2/posicoes_segmentada.csv', 'r')
    
    copia = image.copy()

    try:
      leitor = csv.reader(f)
      leitor = list(leitor)
      leitor.pop(0)
      for linha in leitor:
        if len(linha) > 0:
          # Para cada região dessa imagem:
          if linha[0] == img:
            posicoes = []
            x = int(linha[3])
            y = int(linha[4])
            w = int(linha[5])
            h = int(linha[6])
            
            # Label da região
            label = linha[1]
            if label == 'NC':
              y_true.append(0)
            else:
              y_true.append(1)
            
            # Região
            regiao = image[y: y + h, x: x + w]
            regiao = converte(regiao)
            
            # Coloca a região na função e obtem o resultado
            predicao = model.predict(regiao,batch_size=bSize,verbose=0)
           
            # Probabilidade de ser da classe 1
            prob.append(predicao[0][1])
            
            # Se é um cromossomo:
            if predicao[0][1] > predicao[0][0]:
              y_predict.append(1)
              cv2.rectangle(copia,(x, y),(x+w, y+h),(0,255,0), 1)
            # Se não for um cromossomo:
            else:
              y_predict.append(0)
              cv2.rectangle(copia,(x, y),(x+w, y+h),(0,0,255), 1)
                        
    finally:
      f.close()
    
    cv2.imwrite(local + '/' + img, copia)
  
  return y_true, y_predict, prob

# %% [markdown]
# ---

# %% [markdown]
# # Implementação

# %% [markdown]
# *   Batch size = 32
# *   Image size = 120x120

# %% [markdown]
# ## Variaveis globais

# %% [markdown]
# *   Batch size = 32
# *   Image size = 120x120

# %%
train_path = 'drive/My Drive/Base_CNN/Binarizado3/Train'
test_path = 'drive/My Drive/Base_CNN/Binarizado3/Test'
validation_path = 'drive/My Drive/Base_CNN/Binarizado3/Validation'

# %%
results = {}

# %%
bSize = 32

# %%
datagen = ImageDataGenerator(rescale=1/255.,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            rotation_range=20,
                            shear_range=0.3,
                            horizontal_flip=True)

# %%
train_batches = datagen.flow_from_directory(train_path, target_size=(120, 120), 
                                            classes=['NC', 'C'], 
                                            batch_size=bSize)
validation_batches = datagen.flow_from_directory(validation_path, 
                                                 target_size=(120, 120), 
                                                 classes=['NC', 'C'], 
                                                 batch_size=bSize)

stepsPerEpoche = len(train_batches)/bSize
validationSteps = len(validation_batches)/bSize
# Out:
# Found 4230 images belonging to 2 classes.
# Found 1100 images belonging to 2 classes.

# %%
train_batches.class_indices
# Out:
# {'C': 1, 'NC': 0}

# %% [markdown]
# ---

# %% [markdown]
# ## 1 tentativa - Test Precision: 0.00%, AUC: 0.527, Accuracy: 80.36%

# %% [markdown]
# **Descrição**
#
#
# *   Modelo descrito no artigo "Crowdsourcing for Chromosome Segmentation and Deep Classification"

# %%
architecture = 'architecture_1'

# %% [markdown]
# ### Modelo

# %%
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(120, 120, 3)),
    Conv2D(64, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(32, (3, 3), activation='relu'),
    Conv2D(32, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(16, (3, 3), activation='relu'),
    Conv2D(16, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(8, (3, 3), activation='relu'),
    Conv2D(8, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    Dense(1024, activation='sigmoid'),
    Dense(512, activation='sigmoid'),
   
    Dense(2, activation='softmax')
]
)

# %%
model.compile(SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#  - 46s - loss: 0.7178 - acc: 0.5187 - val_loss: 0.7020 - val_acc: 0.4375
#
# Epoch 00001: val_loss improved from inf to 0.70203, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 2/50
#  - 42s - loss: 0.6981 - acc: 0.5062 - val_loss: 0.7542 - val_acc: 0.4062
#
# Epoch 00002: val_loss did not improve from 0.70203
# Epoch 3/50
#  - 45s - loss: 0.6976 - acc: 0.5062 - val_loss: 0.6935 - val_acc: 0.5000
#
# Epoch 00003: val_loss improved from 0.70203 to 0.69349, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 4/50
#  - 42s - loss: 0.6945 - acc: 0.5000 - val_loss: 0.6927 - val_acc: 0.5156
#
# Epoch 00004: val_loss improved from 0.69349 to 0.69267, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 5/50
#  - 38s - loss: 0.6924 - acc: 0.5250 - val_loss: 0.6935 - val_acc: 0.5312
#
# Epoch 00005: val_loss did not improve from 0.69267
# Epoch 6/50
#  - 41s - loss: 0.6974 - acc: 0.5438 - val_loss: 0.6989 - val_acc: 0.4688
#
# Epoch 00006: val_loss did not improve from 0.69267
# Epoch 7/50
#  - 41s - loss: 0.6928 - acc: 0.5312 - val_loss: 0.6934 - val_acc: 0.4688
#
# Epoch 00007: val_loss did not improve from 0.69267
# Epoch 8/50
#  - 39s - loss: 0.7191 - acc: 0.5000 - val_loss: 0.7021 - val_acc: 0.5312
#
# Epoch 00008: val_loss did not improve from 0.69267
# Epoch 9/50
#  - 43s - loss: 0.7382 - acc: 0.5187 - val_loss: 0.7021 - val_acc: 0.4688
#
# Epoch 00009: val_loss did not improve from 0.69267
# Epoch 10/50
#  - 48s - loss: 0.6931 - acc: 0.5375 - val_loss: 0.6922 - val_acc: 0.5312
#
# Epoch 00010: val_loss improved from 0.69267 to 0.69216, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 11/50
#  - 50s - loss: 0.7129 - acc: 0.4688 - val_loss: 0.6928 - val_acc: 0.5156
#
# Epoch 00011: val_loss did not improve from 0.69216
# Epoch 12/50
#  - 37s - loss: 0.6961 - acc: 0.4937 - val_loss: 0.7249 - val_acc: 0.4375
#
# Epoch 00012: val_loss did not improve from 0.69216
# Epoch 13/50
#  - 36s - loss: 0.7213 - acc: 0.4500 - val_loss: 0.6943 - val_acc: 0.5312
#
# Epoch 00013: val_loss did not improve from 0.69216
# Epoch 14/50
#  - 38s - loss: 0.6959 - acc: 0.5000 - val_loss: 0.6887 - val_acc: 0.5469
#
# Epoch 00014: val_loss improved from 0.69216 to 0.68867, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 15/50
#  - 36s - loss: 0.6951 - acc: 0.4875 - val_loss: 0.7229 - val_acc: 0.4375
#
# Epoch 00015: val_loss did not improve from 0.68867
# Epoch 16/50
#  - 36s - loss: 0.6949 - acc: 0.5125 - val_loss: 0.6828 - val_acc: 0.5781
#
# Epoch 00016: val_loss improved from 0.68867 to 0.68279, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 17/50
#  - 54s - loss: 0.7028 - acc: 0.5250 - val_loss: 0.6942 - val_acc: 0.4531
#
# Epoch 00017: val_loss did not improve from 0.68279
# Epoch 18/50
#  - 41s - loss: 0.6973 - acc: 0.4688 - val_loss: 0.7110 - val_acc: 0.3864
#
# Epoch 00018: val_loss did not improve from 0.68279
# Epoch 19/50
#  - 36s - loss: 0.7040 - acc: 0.5312 - val_loss: 0.7119 - val_acc: 0.4219
#
# Epoch 00019: val_loss did not improve from 0.68279
# Epoch 20/50
#  - 39s - loss: 0.7010 - acc: 0.4750 - val_loss: 0.6836 - val_acc: 0.5781
#
# Epoch 00020: val_loss did not improve from 0.68279
# Epoch 21/50
#  - 42s - loss: 0.7008 - acc: 0.5250 - val_loss: 0.7478 - val_acc: 0.4375
#
# Epoch 00021: val_loss did not improve from 0.68279
# Epoch 22/50
#  - 40s - loss: 0.6960 - acc: 0.5250 - val_loss: 0.6985 - val_acc: 0.5156
#
# Epoch 00022: val_loss did not improve from 0.68279
# Epoch 23/50
#  - 37s - loss: 0.7072 - acc: 0.5750 - val_loss: 0.7100 - val_acc: 0.4531
#
# Epoch 00023: val_loss did not improve from 0.68279
# Epoch 24/50
#  - 56s - loss: 0.7173 - acc: 0.4188 - val_loss: 0.7054 - val_acc: 0.4844
#
# Epoch 00024: val_loss did not improve from 0.68279
# Epoch 25/50
#  - 67s - loss: 0.6992 - acc: 0.5187 - val_loss: 0.7165 - val_acc: 0.3438
#
# Epoch 00025: val_loss did not improve from 0.68279
# Epoch 26/50
#  - 44s - loss: 0.6912 - acc: 0.5500 - val_loss: 0.7461 - val_acc: 0.4219
#
# Epoch 00026: val_loss did not improve from 0.68279
# Epoch 27/50
#  - 20s - loss: 0.7003 - acc: 0.5677 - val_loss: 0.7138 - val_acc: 0.4219
#
# Epoch 00027: val_loss did not improve from 0.68279
# Epoch 28/50
#  - 1s - loss: 0.6941 - acc: 0.5250 - val_loss: 0.6996 - val_acc: 0.4375
#
# Epoch 00028: val_loss did not improve from 0.68279
# Epoch 29/50
#  - 1s - loss: 0.6929 - acc: 0.5312 - val_loss: 0.6988 - val_acc: 0.5156
#
# Epoch 00029: val_loss did not improve from 0.68279
# Epoch 30/50
#  - 1s - loss: 0.7109 - acc: 0.4562 - val_loss: 0.7003 - val_acc: 0.4844
#
# Epoch 00030: val_loss did not improve from 0.68279
# Epoch 31/50
#  - 1s - loss: 0.7047 - acc: 0.4750 - val_loss: 0.6995 - val_acc: 0.4688
#
# Epoch 00031: val_loss did not improve from 0.68279
# Epoch 32/50
#  - 1s - loss: 0.6996 - acc: 0.4937 - val_loss: 0.6810 - val_acc: 0.5781
#
# Epoch 00032: val_loss improved from 0.68279 to 0.68098, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 33/50
#  - 1s - loss: 0.6974 - acc: 0.4813 - val_loss: 0.6952 - val_acc: 0.4688
#
# Epoch 00033: val_loss did not improve from 0.68098
# Epoch 34/50
#  - 1s - loss: 0.7010 - acc: 0.4813 - val_loss: 0.6895 - val_acc: 0.5781
#
# Epoch 00034: val_loss did not improve from 0.68098
# Epoch 35/50
#  - 1s - loss: 0.6987 - acc: 0.4937 - val_loss: 0.6925 - val_acc: 0.5227
#
# Epoch 00035: val_loss did not improve from 0.68098
# Epoch 36/50
#  - 1s - loss: 0.7018 - acc: 0.4813 - val_loss: 0.6970 - val_acc: 0.5156
#
# Epoch 00036: val_loss did not improve from 0.68098
# Epoch 37/50
#  - 1s - loss: 0.7017 - acc: 0.5250 - val_loss: 0.6984 - val_acc: 0.4688
#
# Epoch 00037: val_loss did not improve from 0.68098
# Epoch 38/50
#  - 1s - loss: 0.7100 - acc: 0.5000 - val_loss: 0.6928 - val_acc: 0.5156
#
# Epoch 00038: val_loss did not improve from 0.68098
# Epoch 39/50
#  - 1s - loss: 0.6934 - acc: 0.5187 - val_loss: 0.7036 - val_acc: 0.4844
#
# Epoch 00039: val_loss did not improve from 0.68098
# Epoch 40/50
#  - 1s - loss: 0.6958 - acc: 0.5000 - val_loss: 0.6879 - val_acc: 0.5625
#
# Epoch 00040: val_loss did not improve from 0.68098
# Epoch 41/50
#  - 1s - loss: 0.6959 - acc: 0.5062 - val_loss: 0.6962 - val_acc: 0.5000
#
# Epoch 00041: val_loss did not improve from 0.68098
# Epoch 42/50
#  - 1s - loss: 0.6980 - acc: 0.5125 - val_loss: 0.6920 - val_acc: 0.5312
#
# Epoch 00042: val_loss did not improve from 0.68098
# Epoch 43/50
#  - 1s - loss: 0.6979 - acc: 0.5312 - val_loss: 0.6907 - val_acc: 0.5469
#
# Epoch 00043: val_loss did not improve from 0.68098
# Epoch 44/50
#  - 1s - loss: 0.6952 - acc: 0.5312 - val_loss: 0.6953 - val_acc: 0.4844
#
# Epoch 00044: val_loss did not improve from 0.68098
# Epoch 45/50
#  - 1s - loss: 0.6915 - acc: 0.5438 - val_loss: 0.7420 - val_acc: 0.4688
#
# Epoch 00045: val_loss did not improve from 0.68098
# Epoch 46/50
#  - 1s - loss: 0.7113 - acc: 0.4813 - val_loss: 0.6912 - val_acc: 0.5781
#
# Epoch 00046: val_loss did not improve from 0.68098
# Epoch 47/50
#  - 1s - loss: 0.6978 - acc: 0.4875 - val_loss: 0.6907 - val_acc: 0.5469
#
# Epoch 00047: val_loss did not improve from 0.68098
# Epoch 48/50
#  - 1s - loss: 0.6950 - acc: 0.5062 - val_loss: 0.7059 - val_acc: 0.4688
#
# Epoch 00048: val_loss did not improve from 0.68098
# Epoch 49/50
#  - 1s - loss: 0.7032 - acc: 0.4562 - val_loss: 0.6694 - val_acc: 0.6094
#
# Epoch 00049: val_loss improved from 0.68098 to 0.66943, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_1.hdf5
# Epoch 50/50
#  - 1s - loss: 0.6969 - acc: 0.4750 - val_loss: 0.7228 - val_acc: 0.4375
#
# Epoch 00050: val_loss did not improve from 0.66943

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
len(training.history["val_loss"])
# Out:
# 50

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 0.00%, AUC: 0.527, Accuracy: 80.36%
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 2 tentativa - Test Precision: 19.64%, AUC: 0.487, Accuracy: 19.82%

# %% [markdown]
# **Descrição**
#
#
# *   Modelo descrito no artigo "Crowdsourcing for Chromosome Segmentation and Deep Classification"
# *   Alteração nas duas ultimas camadas Dense

# %%
architecture = 'architecture_2'

# %% [markdown]
# ### Modelo

# %%
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(120, 120, 3)),
    Conv2D(64, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(32, (3, 3), activation='relu'),
    Conv2D(32, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(16, (3, 3), activation='relu'),
    Conv2D(16, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
   
    Conv2D(8, (3, 3), activation='relu'),
    Conv2D(8, (3, 3), activation='relu'),
    Dropout(0.2),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    Dense(512, activation='relu'),
   
    Dense(2, activation='softmax')
]
)

# %%
model.compile(SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 3s - loss: 0.6939 - acc: 0.4375 - val_loss: 0.6937 - val_acc: 0.4531
#
# Epoch 00001: val_loss improved from inf to 0.69367, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 2/50
#  - 1s - loss: 0.6933 - acc: 0.4937 - val_loss: 0.6930 - val_acc: 0.5000
#
# Epoch 00002: val_loss improved from 0.69367 to 0.69299, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 3/50
#  - 1s - loss: 0.6934 - acc: 0.5322 - val_loss: 0.6939 - val_acc: 0.4688
#
# Epoch 00003: val_loss did not improve from 0.69299
# Epoch 4/50
#  - 1s - loss: 0.6919 - acc: 0.5438 - val_loss: 0.6922 - val_acc: 0.5156
#
# Epoch 00004: val_loss improved from 0.69299 to 0.69220, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 5/50
#  - 1s - loss: 0.6935 - acc: 0.4750 - val_loss: 0.6947 - val_acc: 0.3906
#
# Epoch 00005: val_loss did not improve from 0.69220
# Epoch 6/50
#  - 1s - loss: 0.6933 - acc: 0.4438 - val_loss: 0.6918 - val_acc: 0.5312
#
# Epoch 00006: val_loss improved from 0.69220 to 0.69182, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 7/50
#  - 1s - loss: 0.6905 - acc: 0.5687 - val_loss: 0.6932 - val_acc: 0.4531
#
# Epoch 00007: val_loss did not improve from 0.69182
# Epoch 8/50
#  - 1s - loss: 0.6912 - acc: 0.5062 - val_loss: 0.6917 - val_acc: 0.4688
#
# Epoch 00008: val_loss improved from 0.69182 to 0.69170, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 9/50
#  - 1s - loss: 0.6913 - acc: 0.5000 - val_loss: 0.6904 - val_acc: 0.5156
#
# Epoch 00009: val_loss improved from 0.69170 to 0.69035, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 10/50
#  - 1s - loss: 0.6900 - acc: 0.5000 - val_loss: 0.6887 - val_acc: 0.5781
#
# Epoch 00010: val_loss improved from 0.69035 to 0.68869, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 11/50
#  - 1s - loss: 0.6878 - acc: 0.5500 - val_loss: 0.6913 - val_acc: 0.4688
#
# Epoch 00011: val_loss did not improve from 0.68869
# Epoch 12/50
#  - 1s - loss: 0.6895 - acc: 0.4750 - val_loss: 0.6905 - val_acc: 0.4844
#
# Epoch 00012: val_loss did not improve from 0.68869
# Epoch 13/50
#  - 1s - loss: 0.6898 - acc: 0.4688 - val_loss: 0.6895 - val_acc: 0.7031
#
# Epoch 00013: val_loss did not improve from 0.68869
# Epoch 14/50
#  - 1s - loss: 0.6873 - acc: 0.6875 - val_loss: 0.6885 - val_acc: 0.7812
#
# Epoch 00014: val_loss improved from 0.68869 to 0.68847, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 15/50
#  - 1s - loss: 0.6877 - acc: 0.6625 - val_loss: 0.6869 - val_acc: 0.9318
#
# Epoch 00015: val_loss improved from 0.68847 to 0.68690, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 16/50
#  - 1s - loss: 0.6859 - acc: 0.7687 - val_loss: 0.6867 - val_acc: 0.7812
#
# Epoch 00016: val_loss improved from 0.68690 to 0.68675, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 17/50
#  - 1s - loss: 0.6831 - acc: 0.7313 - val_loss: 0.6860 - val_acc: 0.6250
#
# Epoch 00017: val_loss improved from 0.68675 to 0.68595, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 18/50
#  - 1s - loss: 0.6840 - acc: 0.6125 - val_loss: 0.6860 - val_acc: 0.7812
#
# Epoch 00018: val_loss did not improve from 0.68595
# Epoch 19/50
#  - 1s - loss: 0.6845 - acc: 0.7188 - val_loss: 0.6857 - val_acc: 0.8438
#
# Epoch 00019: val_loss improved from 0.68595 to 0.68573, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 20/50
#  - 1s - loss: 0.6824 - acc: 0.8563 - val_loss: 0.6826 - val_acc: 0.9219
#
# Epoch 00020: val_loss improved from 0.68573 to 0.68264, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 21/50
#  - 1s - loss: 0.6812 - acc: 0.8500 - val_loss: 0.6827 - val_acc: 0.9219
#
# Epoch 00021: val_loss did not improve from 0.68264
# Epoch 22/50
#  - 1s - loss: 0.6785 - acc: 0.8125 - val_loss: 0.6815 - val_acc: 0.9375
#
# Epoch 00022: val_loss improved from 0.68264 to 0.68154, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 23/50
#  - 1s - loss: 0.6745 - acc: 0.9062 - val_loss: 0.6820 - val_acc: 0.8594
#
# Epoch 00023: val_loss did not improve from 0.68154
# Epoch 24/50
#  - 1s - loss: 0.6752 - acc: 0.8187 - val_loss: 0.6795 - val_acc: 0.9531
#
# Epoch 00024: val_loss improved from 0.68154 to 0.67951, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 25/50
#  - 1s - loss: 0.6746 - acc: 0.8500 - val_loss: 0.6778 - val_acc: 0.8906
#
# Epoch 00025: val_loss improved from 0.67951 to 0.67780, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 26/50
#  - 1s - loss: 0.6698 - acc: 0.9062 - val_loss: 0.6741 - val_acc: 0.8906
#
# Epoch 00026: val_loss improved from 0.67780 to 0.67409, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 27/50
#  - 1s - loss: 0.6687 - acc: 0.9000 - val_loss: 0.6720 - val_acc: 0.9219
#
# Epoch 00027: val_loss improved from 0.67409 to 0.67199, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 28/50
#  - 1s - loss: 0.6639 - acc: 0.9188 - val_loss: 0.6743 - val_acc: 0.7812
#
# Epoch 00028: val_loss did not improve from 0.67199
# Epoch 29/50
#  - 1s - loss: 0.6626 - acc: 0.9125 - val_loss: 0.6675 - val_acc: 0.8281
#
# Epoch 00029: val_loss improved from 0.67199 to 0.66750, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 30/50
#  - 1s - loss: 0.6484 - acc: 0.9290 - val_loss: 0.6642 - val_acc: 0.9062
#
# Epoch 00030: val_loss improved from 0.66750 to 0.66423, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 31/50
#  - 1s - loss: 0.6484 - acc: 0.8812 - val_loss: 0.6633 - val_acc: 0.8594
#
# Epoch 00031: val_loss improved from 0.66423 to 0.66334, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 32/50
#  - 1s - loss: 0.6318 - acc: 0.8750 - val_loss: 0.6484 - val_acc: 0.8906
#
# Epoch 00032: val_loss improved from 0.66334 to 0.64842, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 33/50
#  - 1s - loss: 0.6303 - acc: 0.8375 - val_loss: 0.6409 - val_acc: 0.8409
#
# Epoch 00033: val_loss improved from 0.64842 to 0.64094, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 34/50
#  - 1s - loss: 0.6090 - acc: 0.8812 - val_loss: 0.6413 - val_acc: 0.8281
#
# Epoch 00034: val_loss did not improve from 0.64094
# Epoch 35/50
#  - 1s - loss: 0.5645 - acc: 0.8187 - val_loss: 0.6101 - val_acc: 0.7812
#
# Epoch 00035: val_loss improved from 0.64094 to 0.61015, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 36/50
#  - 1s - loss: 0.5559 - acc: 0.7562 - val_loss: 0.5999 - val_acc: 0.7969
#
# Epoch 00036: val_loss improved from 0.61015 to 0.59987, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 37/50
#  - 1s - loss: 0.5405 - acc: 0.7438 - val_loss: 0.5531 - val_acc: 0.8438
#
# Epoch 00037: val_loss improved from 0.59987 to 0.55308, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 38/50
#  - 1s - loss: 0.5205 - acc: 0.7500 - val_loss: 0.5903 - val_acc: 0.8438
#
# Epoch 00038: val_loss did not improve from 0.55308
# Epoch 39/50
#  - 1s - loss: 0.5117 - acc: 0.7938 - val_loss: 0.5446 - val_acc: 0.8594
#
# Epoch 00039: val_loss improved from 0.55308 to 0.54461, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 40/50
#  - 1s - loss: 0.5193 - acc: 0.8375 - val_loss: 0.5202 - val_acc: 0.9062
#
# Epoch 00040: val_loss improved from 0.54461 to 0.52021, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 41/50
#  - 1s - loss: 0.5014 - acc: 0.8875 - val_loss: 0.5233 - val_acc: 0.9531
#
# Epoch 00041: val_loss did not improve from 0.52021
# Epoch 42/50
#  - 1s - loss: 0.4428 - acc: 0.8875 - val_loss: 0.5188 - val_acc: 0.9219
#
# Epoch 00042: val_loss improved from 0.52021 to 0.51882, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 43/50
#  - 1s - loss: 0.4471 - acc: 0.8875 - val_loss: 0.5045 - val_acc: 0.9062
#
# Epoch 00043: val_loss improved from 0.51882 to 0.50447, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 44/50
#  - 1s - loss: 0.3606 - acc: 0.9437 - val_loss: 0.4727 - val_acc: 0.9219
#
# Epoch 00044: val_loss improved from 0.50447 to 0.47271, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 45/50
#  - 1s - loss: 0.4472 - acc: 0.8937 - val_loss: 0.5305 - val_acc: 0.8438
#
# Epoch 00045: val_loss did not improve from 0.47271
# Epoch 46/50
#  - 1s - loss: 0.3892 - acc: 0.9188 - val_loss: 0.4724 - val_acc: 0.9062
#
# Epoch 00046: val_loss improved from 0.47271 to 0.47244, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 47/50
#  - 1s - loss: 0.4470 - acc: 0.9125 - val_loss: 0.4558 - val_acc: 0.9219
#
# Epoch 00047: val_loss improved from 0.47244 to 0.45581, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5
# Epoch 48/50
#  - 1s - loss: 0.3684 - acc: 0.9313 - val_loss: 0.4617 - val_acc: 0.8750
#
# Epoch 00048: val_loss did not improve from 0.45581
# Epoch 49/50
#  - 1s - loss: 0.3854 - acc: 0.9250 - val_loss: 0.4983 - val_acc: 0.8438
#
# Epoch 00049: val_loss did not improve from 0.45581
# Epoch 50/50
#  - 1s - loss: 0.3101 - acc: 0.9500 - val_loss: 0.4498 - val_acc: 0.9091
#
# Epoch 00050: val_loss improved from 0.45581 to 0.44977, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_2.hdf5

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.487, Accuracy: 19.82%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 3 tentativa - Test Precision: 19.64%, AUC: 0.096, Accuracy: 19.64%

# %% [markdown]
# Modelo criado pelo **Lucas Valentim**
#
# https://github.com/lucasvalentim/chromosome-recognizer/blob/master/chromosome_recognizer.ipynb

# %%
architecture = 'architecture_3'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/50
#  - 4s - loss: 3.1654 - acc: 0.5625 - val_loss: 1.1686 - val_acc: 0.4844
#
# Epoch 00001: val_loss improved from inf to 1.16857, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 2/50
#  - 0s - loss: 2.9695 - acc: 0.6000 - val_loss: 0.4666 - val_acc: 0.8203
#
# Epoch 00002: val_loss improved from 1.16857 to 0.46663, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 3/50
#  - 0s - loss: 1.5588 - acc: 0.6781 - val_loss: 0.8053 - val_acc: 0.8047
#
# Epoch 00003: val_loss did not improve from 0.46663
# Epoch 4/50
#  - 1s - loss: 1.2319 - acc: 0.7031 - val_loss: 0.7988 - val_acc: 0.8594
#
# Epoch 00004: val_loss did not improve from 0.46663
# Epoch 5/50
#  - 1s - loss: 0.7552 - acc: 0.8031 - val_loss: 1.3301 - val_acc: 0.8594
#
# Epoch 00005: val_loss did not improve from 0.46663
# Epoch 6/50
#  - 1s - loss: 1.0819 - acc: 0.8468 - val_loss: 0.7324 - val_acc: 0.9062
#
# Epoch 00006: val_loss did not improve from 0.46663
# Epoch 7/50
#  - 1s - loss: 0.8958 - acc: 0.8781 - val_loss: 1.4689 - val_acc: 0.6641
#
# Epoch 00007: val_loss did not improve from 0.46663
# Epoch 8/50
#  - 1s - loss: 0.5436 - acc: 0.8875 - val_loss: 0.6025 - val_acc: 0.8828
#
# Epoch 00008: val_loss did not improve from 0.46663
# Epoch 9/50
#  - 1s - loss: 0.3362 - acc: 0.9094 - val_loss: 1.0906 - val_acc: 0.7969
#
# Epoch 00009: val_loss did not improve from 0.46663
# Epoch 10/50
#  - 1s - loss: 0.3604 - acc: 0.9219 - val_loss: 0.8841 - val_acc: 0.8438
#
# Epoch 00010: val_loss did not improve from 0.46663
# Epoch 11/50
#  - 1s - loss: 0.5168 - acc: 0.8906 - val_loss: 0.7872 - val_acc: 0.8203
#
# Epoch 00011: val_loss did not improve from 0.46663
# Epoch 12/50
#  - 1s - loss: 0.2890 - acc: 0.9156 - val_loss: 0.4332 - val_acc: 0.9062
#
# Epoch 00012: val_loss improved from 0.46663 to 0.43320, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 13/50
#  - 1s - loss: 0.4142 - acc: 0.9188 - val_loss: 0.4573 - val_acc: 0.9091
#
# Epoch 00013: val_loss did not improve from 0.43320
# Epoch 14/50
#  - 1s - loss: 0.4064 - acc: 0.8844 - val_loss: 0.3667 - val_acc: 0.9141
#
# Epoch 00014: val_loss improved from 0.43320 to 0.36665, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 15/50
#  - 1s - loss: 0.2762 - acc: 0.9375 - val_loss: 0.4041 - val_acc: 0.8984
#
# Epoch 00015: val_loss did not improve from 0.36665
# Epoch 16/50
#  - 1s - loss: 0.3877 - acc: 0.9219 - val_loss: 0.3403 - val_acc: 0.9219
#
# Epoch 00016: val_loss improved from 0.36665 to 0.34028, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 17/50
#  - 1s - loss: 0.4660 - acc: 0.8844 - val_loss: 0.2337 - val_acc: 0.9609
#
# Epoch 00017: val_loss improved from 0.34028 to 0.23370, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 18/50
#  - 1s - loss: 0.2511 - acc: 0.9188 - val_loss: 0.3274 - val_acc: 0.9531
#
# Epoch 00018: val_loss did not improve from 0.23370
# Epoch 19/50
#  - 1s - loss: 0.2999 - acc: 0.9188 - val_loss: 0.3135 - val_acc: 0.9219
#
# Epoch 00019: val_loss did not improve from 0.23370
# Epoch 20/50
#  - 1s - loss: 0.3066 - acc: 0.9125 - val_loss: 0.3738 - val_acc: 0.8828
#
# Epoch 00020: val_loss did not improve from 0.23370
# Epoch 21/50
#  - 1s - loss: 0.2594 - acc: 0.9094 - val_loss: 0.0883 - val_acc: 0.9844
#
# Epoch 00021: val_loss improved from 0.23370 to 0.08826, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_3.hdf5
# Epoch 22/50
#  - 1s - loss: 0.3160 - acc: 0.9188 - val_loss: 0.4842 - val_acc: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.08826
# Epoch 23/50
#  - 1s - loss: 0.3281 - acc: 0.8812 - val_loss: 0.3947 - val_acc: 0.8516
#
# Epoch 00023: val_loss did not improve from 0.08826
# Epoch 24/50
#  - 1s - loss: 0.2542 - acc: 0.9188 - val_loss: 0.5337 - val_acc: 0.8672
#
# Epoch 00024: val_loss did not improve from 0.08826
# Epoch 25/50
#  - 1s - loss: 0.2409 - acc: 0.9437 - val_loss: 0.3752 - val_acc: 0.9062
#
# Epoch 00025: val_loss did not improve from 0.08826
# Epoch 26/50
#  - 1s - loss: 0.2331 - acc: 0.9219 - val_loss: 0.8563 - val_acc: 0.7969
#
# Epoch 00026: val_loss did not improve from 0.08826
# Epoch 27/50
#  - 1s - loss: 0.2270 - acc: 0.9281 - val_loss: 0.6708 - val_acc: 0.8281
#
# Epoch 00027: val_loss did not improve from 0.08826
# Epoch 28/50
#  - 1s - loss: 0.2140 - acc: 0.9469 - val_loss: 0.4256 - val_acc: 0.9219
#
# Epoch 00028: val_loss did not improve from 0.08826
# Epoch 29/50
#  - 1s - loss: 0.2961 - acc: 0.9281 - val_loss: 0.1988 - val_acc: 0.9531
#
# Epoch 00029: val_loss did not improve from 0.08826
# Epoch 30/50
#  - 1s - loss: 0.2647 - acc: 0.9188 - val_loss: 0.3424 - val_acc: 0.9091
#
# Epoch 00030: val_loss did not improve from 0.08826
# Epoch 31/50
#  - 1s - loss: 0.2227 - acc: 0.9250 - val_loss: 0.3254 - val_acc: 0.9141
#
# Epoch 00031: val_loss did not improve from 0.08826
# Epoch 32/50
#  - 1s - loss: 0.3162 - acc: 0.9094 - val_loss: 0.4553 - val_acc: 0.9062
#
# Epoch 00032: val_loss did not improve from 0.08826
# Epoch 33/50
#  - 1s - loss: 0.2307 - acc: 0.9548 - val_loss: 0.2774 - val_acc: 0.9375
#
# Epoch 00033: val_loss did not improve from 0.08826
# Epoch 34/50
#  - 1s - loss: 0.1907 - acc: 0.9625 - val_loss: 0.5225 - val_acc: 0.7891
#
# Epoch 00034: val_loss did not improve from 0.08826
# Epoch 35/50
#  - 1s - loss: 0.2944 - acc: 0.9031 - val_loss: 0.5740 - val_acc: 0.8125
#
# Epoch 00035: val_loss did not improve from 0.08826
# Epoch 36/50
#  - 1s - loss: 0.2132 - acc: 0.9375 - val_loss: 0.1739 - val_acc: 0.9609
#
# Epoch 00036: val_loss did not improve from 0.08826
# Epoch 37/50
#  - 1s - loss: 0.1679 - acc: 0.9750 - val_loss: 0.2326 - val_acc: 0.9062
#
# Epoch 00037: val_loss did not improve from 0.08826
# Epoch 38/50
#  - 1s - loss: 0.2368 - acc: 0.9469 - val_loss: 0.1737 - val_acc: 0.9453
#
# Epoch 00038: val_loss did not improve from 0.08826
# Epoch 39/50
#  - 1s - loss: 0.2028 - acc: 0.9406 - val_loss: 0.6824 - val_acc: 0.7891
#
# Epoch 00039: val_loss did not improve from 0.08826
# Epoch 40/50
#  - 1s - loss: 0.3554 - acc: 0.8781 - val_loss: 0.3112 - val_acc: 0.8750
#
# Epoch 00040: val_loss did not improve from 0.08826
# Epoch 41/50
#  - 1s - loss: 0.2659 - acc: 0.9094 - val_loss: 0.2245 - val_acc: 0.9297
#
# Epoch 00041: val_loss did not improve from 0.08826
# Epoch 42/50
#  - 1s - loss: 0.2480 - acc: 0.9469 - val_loss: 0.3539 - val_acc: 0.8984
#
# Epoch 00042: val_loss did not improve from 0.08826
# Epoch 43/50
#  - 1s - loss: 0.1813 - acc: 0.9406 - val_loss: 0.2130 - val_acc: 0.9531
#
# Epoch 00043: val_loss did not improve from 0.08826
# Epoch 44/50
#  - 1s - loss: 0.1992 - acc: 0.9437 - val_loss: 0.3508 - val_acc: 0.9141
#
# Epoch 00044: val_loss did not improve from 0.08826
# Epoch 45/50
#  - 1s - loss: 0.2208 - acc: 0.9281 - val_loss: 0.6523 - val_acc: 0.7812
#
# Epoch 00045: val_loss did not improve from 0.08826
# Epoch 46/50
#  - 1s - loss: 0.3668 - acc: 0.9062 - val_loss: 0.2088 - val_acc: 0.9297
#
# Epoch 00046: val_loss did not improve from 0.08826
# Epoch 47/50
#  - 1s - loss: 0.2135 - acc: 0.9500 - val_loss: 0.3652 - val_acc: 0.9062
#
# Epoch 00047: val_loss did not improve from 0.08826
# Epoch 48/50
#  - 1s - loss: 0.2766 - acc: 0.9250 - val_loss: 0.2120 - val_acc: 0.9545
#
# Epoch 00048: val_loss did not improve from 0.08826
# Epoch 49/50
#  - 1s - loss: 0.1988 - acc: 0.9344 - val_loss: 0.4238 - val_acc: 0.8906
#
# Epoch 00049: val_loss did not improve from 0.08826
# Epoch 50/50
#  - 1s - loss: 0.2870 - acc: 0.9062 - val_loss: 0.2597 - val_acc: 0.9219
#
# Epoch 00050: val_loss did not improve from 0.08826

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.096, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 4 tentativa - Test Precision: 20.13%, AUC: 0.425, Accuracy: 22.07%

# %% [markdown]
# Modelo adaptado do **Lucas Valentim**
#
# *   Sem os **dropout**

# %%
architecture = 'architecture_4'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 5s - loss: 0.4733 - acc: 0.8031 - val_loss: 2.2918 - val_acc: 0.5938
#
# Epoch 00001: val_loss improved from inf to 2.29182, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_4.hdf5
# Epoch 2/50
#  - 1s - loss: 0.3785 - acc: 0.9031 - val_loss: 1.6535 - val_acc: 0.7188
#
# Epoch 00002: val_loss improved from 2.29182 to 1.65350, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_4.hdf5
# Epoch 3/50
#  - 0s - loss: 0.2671 - acc: 0.9281 - val_loss: 0.2163 - val_acc: 0.9688
#
# Epoch 00003: val_loss improved from 1.65350 to 0.21634, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_4.hdf5
# Epoch 4/50
#  - 1s - loss: 0.2807 - acc: 0.9156 - val_loss: 0.4641 - val_acc: 0.8203
#
# Epoch 00004: val_loss did not improve from 0.21634
# Epoch 5/50
#  - 2s - loss: 0.3062 - acc: 0.9281 - val_loss: 1.1855 - val_acc: 0.6094
#
# Epoch 00005: val_loss did not improve from 0.21634
# Epoch 6/50
#  - 1s - loss: 0.2180 - acc: 0.9437 - val_loss: 0.7924 - val_acc: 0.7109
#
# Epoch 00006: val_loss did not improve from 0.21634
# Epoch 7/50
#  - 1s - loss: 0.1633 - acc: 0.9656 - val_loss: 0.5131 - val_acc: 0.8984
#
# Epoch 00007: val_loss did not improve from 0.21634
# Epoch 8/50
#  - 1s - loss: 0.2731 - acc: 0.9188 - val_loss: 0.5356 - val_acc: 0.8438
#
# Epoch 00008: val_loss did not improve from 0.21634
# Epoch 9/50
#  - 1s - loss: 0.3237 - acc: 0.9226 - val_loss: 1.3003 - val_acc: 0.6328
#
# Epoch 00009: val_loss did not improve from 0.21634
# Epoch 10/50
#  - 1s - loss: 0.2824 - acc: 0.9375 - val_loss: 0.3231 - val_acc: 0.8977
#
# Epoch 00010: val_loss did not improve from 0.21634
# Epoch 11/50
#  - 1s - loss: 0.3049 - acc: 0.9375 - val_loss: 0.2417 - val_acc: 0.9219
#
# Epoch 00011: val_loss did not improve from 0.21634
# Epoch 12/50
#  - 1s - loss: 0.2273 - acc: 0.9250 - val_loss: 0.4177 - val_acc: 0.8828
#
# Epoch 00012: val_loss did not improve from 0.21634
# Epoch 13/50
#  - 1s - loss: 0.2144 - acc: 0.9562 - val_loss: 0.5390 - val_acc: 0.8672
#
# Epoch 00013: val_loss did not improve from 0.21634
# Epoch 14/50
#  - 1s - loss: 0.2305 - acc: 0.9437 - val_loss: 0.3861 - val_acc: 0.9297
#
# Epoch 00014: val_loss did not improve from 0.21634
# Epoch 15/50
#  - 1s - loss: 0.2821 - acc: 0.8875 - val_loss: 0.4651 - val_acc: 0.8750
#
# Epoch 00015: val_loss did not improve from 0.21634
# Epoch 16/50
#  - 1s - loss: 0.1850 - acc: 0.9562 - val_loss: 0.5681 - val_acc: 0.8516
#
# Epoch 00016: val_loss did not improve from 0.21634
# Epoch 17/50
#  - 1s - loss: 0.2178 - acc: 0.9375 - val_loss: 0.2716 - val_acc: 0.9141
#
# Epoch 00017: val_loss did not improve from 0.21634
# Epoch 18/50
#  - 1s - loss: 0.2756 - acc: 0.9250 - val_loss: 0.3455 - val_acc: 0.9375
#
# Epoch 00018: val_loss did not improve from 0.21634
# Epoch 19/50
#  - 1s - loss: 0.1956 - acc: 0.9562 - val_loss: 0.5100 - val_acc: 0.8672
#
# Epoch 00019: val_loss did not improve from 0.21634
# Epoch 20/50
#  - 1s - loss: 0.2491 - acc: 0.9250 - val_loss: 0.5810 - val_acc: 0.8203
#
# Epoch 00020: val_loss did not improve from 0.21634
# Epoch 21/50
#  - 1s - loss: 0.2480 - acc: 0.9313 - val_loss: 0.3579 - val_acc: 0.9141
#
# Epoch 00021: val_loss did not improve from 0.21634
# Epoch 22/50
#  - 1s - loss: 0.1784 - acc: 0.9562 - val_loss: 0.5922 - val_acc: 0.8594
#
# Epoch 00022: val_loss did not improve from 0.21634
# Epoch 23/50
#  - 1s - loss: 0.2348 - acc: 0.9250 - val_loss: 0.2566 - val_acc: 0.9375
#
# Epoch 00023: val_loss did not improve from 0.21634
# Epoch 24/50
#  - 1s - loss: 0.2576 - acc: 0.9469 - val_loss: 0.3189 - val_acc: 0.9141
#
# Epoch 00024: val_loss did not improve from 0.21634
# Epoch 25/50
#  - 1s - loss: 0.2390 - acc: 0.9437 - val_loss: 0.3359 - val_acc: 0.8516
#
# Epoch 00025: val_loss did not improve from 0.21634
# Epoch 26/50
#  - 1s - loss: 0.1923 - acc: 0.9562 - val_loss: 0.3525 - val_acc: 0.8125
#
# Epoch 00026: val_loss did not improve from 0.21634
# Epoch 27/50
#  - 1s - loss: 0.2163 - acc: 0.9406 - val_loss: 0.3489 - val_acc: 0.8828
#
# Epoch 00027: val_loss did not improve from 0.21634
# Epoch 28/50
#  - 1s - loss: 0.2192 - acc: 0.9375 - val_loss: 0.4070 - val_acc: 0.8295
#
# Epoch 00028: val_loss did not improve from 0.21634
# Epoch 29/50
#  - 1s - loss: 0.2329 - acc: 0.9437 - val_loss: 0.3070 - val_acc: 0.9062
#
# Epoch 00029: val_loss did not improve from 0.21634
# Epoch 30/50
#  - 1s - loss: 0.1541 - acc: 0.9594 - val_loss: 0.3681 - val_acc: 0.9062
#
# Epoch 00030: val_loss did not improve from 0.21634
# Epoch 31/50
#  - 1s - loss: 0.1943 - acc: 0.9437 - val_loss: 0.1408 - val_acc: 0.9531
#
# Epoch 00031: val_loss improved from 0.21634 to 0.14076, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_4.hdf5
# Epoch 32/50
#  - 1s - loss: 0.2253 - acc: 0.9313 - val_loss: 0.4640 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.14076
# Epoch 33/50
#  - 1s - loss: 0.2346 - acc: 0.9219 - val_loss: 0.6830 - val_acc: 0.8203
#
# Epoch 00033: val_loss did not improve from 0.14076
# Epoch 34/50
#  - 1s - loss: 0.2777 - acc: 0.9219 - val_loss: 0.4328 - val_acc: 0.8359
#
# Epoch 00034: val_loss did not improve from 0.14076
# Epoch 35/50
#  - 1s - loss: 0.2458 - acc: 0.9156 - val_loss: 0.3407 - val_acc: 0.8828
#
# Epoch 00035: val_loss did not improve from 0.14076
# Epoch 36/50
#  - 1s - loss: 0.1375 - acc: 0.9774 - val_loss: 0.5464 - val_acc: 0.7891
#
# Epoch 00036: val_loss did not improve from 0.14076
# Epoch 37/50
#  - 1s - loss: 0.2621 - acc: 0.9313 - val_loss: 0.5622 - val_acc: 0.8516
#
# Epoch 00037: val_loss did not improve from 0.14076
# Epoch 38/50
#  - 1s - loss: 0.2882 - acc: 0.9219 - val_loss: 0.3524 - val_acc: 0.8906
#
# Epoch 00038: val_loss did not improve from 0.14076
# Epoch 39/50
#  - 1s - loss: 0.2427 - acc: 0.9250 - val_loss: 0.2136 - val_acc: 0.9688
#
# Epoch 00039: val_loss did not improve from 0.14076
# Epoch 40/50
#  - 1s - loss: 0.1749 - acc: 0.9469 - val_loss: 0.4240 - val_acc: 0.8750
#
# Epoch 00040: val_loss did not improve from 0.14076
# Epoch 41/50
#  - 1s - loss: 0.2959 - acc: 0.9156 - val_loss: 0.5715 - val_acc: 0.8281
#
# Epoch 00041: val_loss did not improve from 0.14076
# Epoch 42/50
#  - 1s - loss: 0.1906 - acc: 0.9500 - val_loss: 0.3074 - val_acc: 0.9297
#
# Epoch 00042: val_loss did not improve from 0.14076
# Epoch 43/50
#  - 1s - loss: 0.1866 - acc: 0.9500 - val_loss: 0.2948 - val_acc: 0.8984
#
# Epoch 00043: val_loss did not improve from 0.14076
# Epoch 44/50
#  - 1s - loss: 0.2534 - acc: 0.9125 - val_loss: 0.4140 - val_acc: 0.8906
#
# Epoch 00044: val_loss did not improve from 0.14076
# Epoch 45/50
#  - 1s - loss: 0.2161 - acc: 0.9437 - val_loss: 0.4036 - val_acc: 0.8409
#
# Epoch 00045: val_loss did not improve from 0.14076
# Epoch 46/50
#  - 1s - loss: 0.1627 - acc: 0.9688 - val_loss: 0.2993 - val_acc: 0.8906
#
# Epoch 00046: val_loss did not improve from 0.14076
# Epoch 47/50
#  - 1s - loss: 0.2205 - acc: 0.9156 - val_loss: 0.2787 - val_acc: 0.9219
#
# Epoch 00047: val_loss did not improve from 0.14076
# Epoch 48/50
#  - 1s - loss: 0.3048 - acc: 0.9188 - val_loss: 0.4147 - val_acc: 0.8828
#
# Epoch 00048: val_loss did not improve from 0.14076
# Epoch 49/50
#  - 1s - loss: 0.2440 - acc: 0.9344 - val_loss: 0.3826 - val_acc: 0.8828
#
# Epoch 00049: val_loss did not improve from 0.14076
# Epoch 50/50
#  - 1s - loss: 0.2245 - acc: 0.9094 - val_loss: 0.2937 - val_acc: 0.9219
#
# Epoch 00050: val_loss did not improve from 0.14076

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 20.13%, AUC: 0.425, Accuracy: 22.07%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 5 tentativa - Test Precision: 19.64%, AUC: 0.287, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Sem os **dropout**
# *   Função **SGD** para compilação

# %%
architecture = 'architecture_5'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 4s - loss: 5.4950 - acc: 0.4844 - val_loss: 4.3959 - val_acc: 0.6094
#
# Epoch 00001: val_loss improved from inf to 4.39590, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 2/50
#  - 0s - loss: 4.8085 - acc: 0.5375 - val_loss: 2.6518 - val_acc: 0.5859
#
# Epoch 00002: val_loss improved from 4.39590 to 2.65180, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 3/50
#  - 0s - loss: 6.5174 - acc: 0.4156 - val_loss: 1.8159 - val_acc: 0.7188
#
# Epoch 00003: val_loss improved from 2.65180 to 1.81587, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 4/50
#  - 1s - loss: 2.4970 - acc: 0.6437 - val_loss: 0.8537 - val_acc: 0.7969
#
# Epoch 00004: val_loss improved from 1.81587 to 0.85373, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 5/50
#  - 1s - loss: 0.7803 - acc: 0.8625 - val_loss: 1.5103 - val_acc: 0.6484
#
# Epoch 00005: val_loss did not improve from 0.85373
# Epoch 6/50
#  - 1s - loss: 0.8481 - acc: 0.8469 - val_loss: 0.2691 - val_acc: 0.9531
#
# Epoch 00006: val_loss improved from 0.85373 to 0.26908, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 7/50
#  - 1s - loss: 0.6206 - acc: 0.9094 - val_loss: 0.8846 - val_acc: 0.8359
#
# Epoch 00007: val_loss did not improve from 0.26908
# Epoch 8/50
#  - 1s - loss: 0.4835 - acc: 0.8875 - val_loss: 0.6882 - val_acc: 0.8977
#
# Epoch 00008: val_loss did not improve from 0.26908
# Epoch 9/50
#  - 1s - loss: 0.5561 - acc: 0.8906 - val_loss: 0.3939 - val_acc: 0.9297
#
# Epoch 00009: val_loss did not improve from 0.26908
# Epoch 10/50
#  - 1s - loss: 0.3808 - acc: 0.9125 - val_loss: 0.3284 - val_acc: 0.9062
#
# Epoch 00010: val_loss did not improve from 0.26908
# Epoch 11/50
#  - 1s - loss: 0.3589 - acc: 0.9250 - val_loss: 0.1086 - val_acc: 0.9688
#
# Epoch 00011: val_loss improved from 0.26908 to 0.10857, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_5.hdf5
# Epoch 12/50
#  - 1s - loss: 0.6512 - acc: 0.8581 - val_loss: 0.9419 - val_acc: 0.6172
#
# Epoch 00012: val_loss did not improve from 0.10857
# Epoch 13/50
#  - 1s - loss: 0.2832 - acc: 0.9156 - val_loss: 0.5875 - val_acc: 0.7500
#
# Epoch 00013: val_loss did not improve from 0.10857
# Epoch 14/50
#  - 1s - loss: 0.3885 - acc: 0.9031 - val_loss: 0.4635 - val_acc: 0.8594
#
# Epoch 00014: val_loss did not improve from 0.10857
# Epoch 15/50
#  - 1s - loss: 0.5747 - acc: 0.8625 - val_loss: 0.4776 - val_acc: 0.8281
#
# Epoch 00015: val_loss did not improve from 0.10857
# Epoch 16/50
#  - 1s - loss: 0.2611 - acc: 0.9344 - val_loss: 0.2439 - val_acc: 0.9609
#
# Epoch 00016: val_loss did not improve from 0.10857
# Epoch 17/50
#  - 1s - loss: 0.3788 - acc: 0.9031 - val_loss: 0.2246 - val_acc: 0.9453
#
# Epoch 00017: val_loss did not improve from 0.10857
# Epoch 18/50
#  - 1s - loss: 0.2745 - acc: 0.9500 - val_loss: 0.3134 - val_acc: 0.9219
#
# Epoch 00018: val_loss did not improve from 0.10857
# Epoch 19/50
#  - 1s - loss: 0.2575 - acc: 0.9344 - val_loss: 0.4520 - val_acc: 0.9062
#
# Epoch 00019: val_loss did not improve from 0.10857
# Epoch 20/50
#  - 1s - loss: 0.2799 - acc: 0.9344 - val_loss: 0.3630 - val_acc: 0.8984
#
# Epoch 00020: val_loss did not improve from 0.10857
# Epoch 21/50
#  - 1s - loss: 0.2667 - acc: 0.9437 - val_loss: 0.4638 - val_acc: 0.8906
#
# Epoch 00021: val_loss did not improve from 0.10857
# Epoch 22/50
#  - 1s - loss: 0.2104 - acc: 0.9437 - val_loss: 0.8763 - val_acc: 0.7969
#
# Epoch 00022: val_loss did not improve from 0.10857
# Epoch 23/50
#  - 1s - loss: 0.2318 - acc: 0.9625 - val_loss: 0.4375 - val_acc: 0.9062
#
# Epoch 00023: val_loss did not improve from 0.10857
# Epoch 24/50
#  - 1s - loss: 0.3361 - acc: 0.8875 - val_loss: 0.3967 - val_acc: 0.8750
#
# Epoch 00024: val_loss did not improve from 0.10857
# Epoch 25/50
#  - 1s - loss: 0.3027 - acc: 0.9188 - val_loss: 0.3286 - val_acc: 0.8523
#
# Epoch 00025: val_loss did not improve from 0.10857
# Epoch 26/50
#  - 1s - loss: 0.3710 - acc: 0.8969 - val_loss: 0.4067 - val_acc: 0.8594
#
# Epoch 00026: val_loss did not improve from 0.10857
# Epoch 27/50
#  - 1s - loss: 0.2884 - acc: 0.9219 - val_loss: 0.3303 - val_acc: 0.9375
#
# Epoch 00027: val_loss did not improve from 0.10857
# Epoch 28/50
#  - 1s - loss: 0.3079 - acc: 0.9313 - val_loss: 0.3174 - val_acc: 0.9219
#
# Epoch 00028: val_loss did not improve from 0.10857
# Epoch 29/50
#  - 1s - loss: 0.2414 - acc: 0.9437 - val_loss: 0.3232 - val_acc: 0.9219
#
# Epoch 00029: val_loss did not improve from 0.10857
# Epoch 30/50
#  - 1s - loss: 0.2416 - acc: 0.9281 - val_loss: 0.3190 - val_acc: 0.9219
#
# Epoch 00030: val_loss did not improve from 0.10857
# Epoch 31/50
#  - 1s - loss: 0.2740 - acc: 0.9375 - val_loss: 0.3255 - val_acc: 0.8750
#
# Epoch 00031: val_loss did not improve from 0.10857
# Epoch 32/50
#  - 1s - loss: 0.2262 - acc: 0.9375 - val_loss: 0.5009 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.10857
# Epoch 33/50
#  - 1s - loss: 0.2557 - acc: 0.9156 - val_loss: 0.1783 - val_acc: 0.9531
#
# Epoch 00033: val_loss did not improve from 0.10857
# Epoch 34/50
#  - 1s - loss: 0.2757 - acc: 0.9188 - val_loss: 0.2417 - val_acc: 0.9453
#
# Epoch 00034: val_loss did not improve from 0.10857
# Epoch 35/50
#  - 1s - loss: 0.2777 - acc: 0.9094 - val_loss: 0.2411 - val_acc: 0.9375
#
# Epoch 00035: val_loss did not improve from 0.10857
# Epoch 36/50
#  - 1s - loss: 0.2066 - acc: 0.9437 - val_loss: 0.3062 - val_acc: 0.9062
#
# Epoch 00036: val_loss did not improve from 0.10857
# Epoch 37/50
#  - 1s - loss: 0.3085 - acc: 0.9219 - val_loss: 0.3262 - val_acc: 0.9141
#
# Epoch 00037: val_loss did not improve from 0.10857
# Epoch 38/50
#  - 1s - loss: 0.2655 - acc: 0.9344 - val_loss: 0.5678 - val_acc: 0.8438
#
# Epoch 00038: val_loss did not improve from 0.10857
# Epoch 39/50
#  - 1s - loss: 0.1863 - acc: 0.9581 - val_loss: 0.2085 - val_acc: 0.9375
#
# Epoch 00039: val_loss did not improve from 0.10857
# Epoch 40/50
#  - 1s - loss: 0.2639 - acc: 0.9406 - val_loss: 0.4889 - val_acc: 0.8359
#
# Epoch 00040: val_loss did not improve from 0.10857
# Epoch 41/50
#  - 1s - loss: 0.2602 - acc: 0.9250 - val_loss: 0.1679 - val_acc: 0.9609
#
# Epoch 00041: val_loss did not improve from 0.10857
# Epoch 42/50
#  - 1s - loss: 0.3138 - acc: 0.9094 - val_loss: 0.4201 - val_acc: 0.8828
#
# Epoch 00042: val_loss did not improve from 0.10857
# Epoch 43/50
#  - 1s - loss: 0.2670 - acc: 0.9125 - val_loss: 0.3384 - val_acc: 0.8977
#
# Epoch 00043: val_loss did not improve from 0.10857
# Epoch 44/50
#  - 1s - loss: 0.1945 - acc: 0.9437 - val_loss: 0.3967 - val_acc: 0.9219
#
# Epoch 00044: val_loss did not improve from 0.10857
# Epoch 45/50
#  - 1s - loss: 0.2140 - acc: 0.9625 - val_loss: 0.1970 - val_acc: 0.9531
#
# Epoch 00045: val_loss did not improve from 0.10857
# Epoch 46/50
#  - 1s - loss: 0.2558 - acc: 0.9344 - val_loss: 0.3620 - val_acc: 0.8906
#
# Epoch 00046: val_loss did not improve from 0.10857
# Epoch 47/50
#  - 1s - loss: 0.1870 - acc: 0.9500 - val_loss: 0.3720 - val_acc: 0.8984
#
# Epoch 00047: val_loss did not improve from 0.10857
# Epoch 48/50
#  - 1s - loss: 0.2909 - acc: 0.9375 - val_loss: 0.3439 - val_acc: 0.9062
#
# Epoch 00048: val_loss did not improve from 0.10857
# Epoch 49/50
#  - 1s - loss: 0.2022 - acc: 0.9531 - val_loss: 0.4179 - val_acc: 0.8750
#
# Epoch 00049: val_loss did not improve from 0.10857
# Epoch 50/50
#  - 1s - loss: 0.2670 - acc: 0.9531 - val_loss: 0.2481 - val_acc: 0.9062
#
# Epoch 00050: val_loss did not improve from 0.10857

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.287, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 6 tentativa - Test Precision: 62.29%, AUC: 0.931, Accuracy: 81.66%

# %% [markdown]
# Modelo adaptado do **Lucas Valentim**
#
# *   Sem os **dropout**
# *   Função **SGD** para compilação
# *   **BatchNormalization** antes da ultima camada Dense

# %%
architecture = 'architecture_6'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(SGD(lr=0.03, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 5s - loss: 0.5799 - acc: 0.7219 - val_loss: 1.7402 - val_acc: 0.5859
#
# Epoch 00001: val_loss improved from inf to 1.74016, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 2/50
#  - 0s - loss: 0.3398 - acc: 0.8875 - val_loss: 0.6005 - val_acc: 0.8125
#
# Epoch 00002: val_loss improved from 1.74016 to 0.60050, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 3/50
#  - 0s - loss: 0.2157 - acc: 0.9531 - val_loss: 0.9164 - val_acc: 0.7812
#
# Epoch 00003: val_loss did not improve from 0.60050
# Epoch 4/50
#  - 1s - loss: 0.3164 - acc: 0.9188 - val_loss: 0.3793 - val_acc: 0.9062
#
# Epoch 00004: val_loss improved from 0.60050 to 0.37934, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 5/50
#  - 2s - loss: 0.2837 - acc: 0.9094 - val_loss: 0.4188 - val_acc: 0.8636
#
# Epoch 00005: val_loss did not improve from 0.37934
# Epoch 6/50
#  - 1s - loss: 0.2541 - acc: 0.9344 - val_loss: 0.2550 - val_acc: 0.9531
#
# Epoch 00006: val_loss improved from 0.37934 to 0.25496, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 7/50
#  - 1s - loss: 0.2875 - acc: 0.9281 - val_loss: 0.8999 - val_acc: 0.5781
#
# Epoch 00007: val_loss did not improve from 0.25496
# Epoch 8/50
#  - 1s - loss: 0.2410 - acc: 0.9344 - val_loss: 0.3542 - val_acc: 0.8672
#
# Epoch 00008: val_loss did not improve from 0.25496
# Epoch 9/50
#  - 1s - loss: 0.2870 - acc: 0.9188 - val_loss: 0.6677 - val_acc: 0.6406
#
# Epoch 00009: val_loss did not improve from 0.25496
# Epoch 10/50
#  - 1s - loss: 0.2250 - acc: 0.9375 - val_loss: 0.9144 - val_acc: 0.5391
#
# Epoch 00010: val_loss did not improve from 0.25496
# Epoch 11/50
#  - 1s - loss: 0.3054 - acc: 0.9125 - val_loss: 1.3476 - val_acc: 0.5078
#
# Epoch 00011: val_loss did not improve from 0.25496
# Epoch 12/50
#  - 1s - loss: 0.2048 - acc: 0.9375 - val_loss: 0.4876 - val_acc: 0.8906
#
# Epoch 00012: val_loss did not improve from 0.25496
# Epoch 13/50
#  - 1s - loss: 0.3125 - acc: 0.9313 - val_loss: 0.6053 - val_acc: 0.6797
#
# Epoch 00013: val_loss did not improve from 0.25496
# Epoch 14/50
#  - 1s - loss: 0.2052 - acc: 0.9437 - val_loss: 0.6084 - val_acc: 0.6797
#
# Epoch 00014: val_loss did not improve from 0.25496
# Epoch 15/50
#  - 1s - loss: 0.5593 - acc: 0.7936 - val_loss: 2.3954 - val_acc: 0.6016
#
# Epoch 00015: val_loss did not improve from 0.25496
# Epoch 16/50
#  - 1s - loss: 0.3405 - acc: 0.8688 - val_loss: 0.4782 - val_acc: 0.7969
#
# Epoch 00016: val_loss did not improve from 0.25496
# Epoch 17/50
#  - 1s - loss: 0.3168 - acc: 0.9000 - val_loss: 0.2782 - val_acc: 0.9062
#
# Epoch 00017: val_loss did not improve from 0.25496
# Epoch 18/50
#  - 1s - loss: 0.2243 - acc: 0.9437 - val_loss: 0.3804 - val_acc: 0.8906
#
# Epoch 00018: val_loss did not improve from 0.25496
# Epoch 19/50
#  - 1s - loss: 0.2334 - acc: 0.9531 - val_loss: 0.3746 - val_acc: 0.8906
#
# Epoch 00019: val_loss did not improve from 0.25496
# Epoch 20/50
#  - 1s - loss: 0.2761 - acc: 0.9031 - val_loss: 0.2973 - val_acc: 0.8828
#
# Epoch 00020: val_loss did not improve from 0.25496
# Epoch 21/50
#  - 1s - loss: 0.1675 - acc: 0.9594 - val_loss: 0.3587 - val_acc: 0.8984
#
# Epoch 00021: val_loss did not improve from 0.25496
# Epoch 22/50
#  - 1s - loss: 0.1200 - acc: 0.9844 - val_loss: 0.5993 - val_acc: 0.8672
#
# Epoch 00022: val_loss did not improve from 0.25496
# Epoch 23/50
#  - 1s - loss: 0.3273 - acc: 0.9156 - val_loss: 0.3739 - val_acc: 0.8409
#
# Epoch 00023: val_loss did not improve from 0.25496
# Epoch 24/50
#  - 1s - loss: 0.2263 - acc: 0.9375 - val_loss: 0.4821 - val_acc: 0.8047
#
# Epoch 00024: val_loss did not improve from 0.25496
# Epoch 25/50
#  - 1s - loss: 0.1274 - acc: 0.9688 - val_loss: 0.4153 - val_acc: 0.8906
#
# Epoch 00025: val_loss did not improve from 0.25496
# Epoch 26/50
#  - 1s - loss: 0.2360 - acc: 0.9437 - val_loss: 0.5477 - val_acc: 0.7812
#
# Epoch 00026: val_loss did not improve from 0.25496
# Epoch 27/50
#  - 1s - loss: 0.2638 - acc: 0.9219 - val_loss: 0.2405 - val_acc: 0.9531
#
# Epoch 00027: val_loss improved from 0.25496 to 0.24046, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 28/50
#  - 1s - loss: 0.2550 - acc: 0.9375 - val_loss: 0.4301 - val_acc: 0.8594
#
# Epoch 00028: val_loss did not improve from 0.24046
# Epoch 29/50
#  - 1s - loss: 0.2253 - acc: 0.9437 - val_loss: 0.5113 - val_acc: 0.8125
#
# Epoch 00029: val_loss did not improve from 0.24046
# Epoch 30/50
#  - 1s - loss: 0.2005 - acc: 0.9594 - val_loss: 0.4919 - val_acc: 0.8125
#
# Epoch 00030: val_loss did not improve from 0.24046
# Epoch 31/50
#  - 1s - loss: 0.2662 - acc: 0.9375 - val_loss: 0.4522 - val_acc: 0.8594
#
# Epoch 00031: val_loss did not improve from 0.24046
# Epoch 32/50
#  - 1s - loss: 0.2224 - acc: 0.9375 - val_loss: 0.2518 - val_acc: 0.8984
#
# Epoch 00032: val_loss did not improve from 0.24046
# Epoch 33/50
#  - 1s - loss: 0.2003 - acc: 0.9531 - val_loss: 0.3694 - val_acc: 0.8984
#
# Epoch 00033: val_loss did not improve from 0.24046
# Epoch 34/50
#  - 1s - loss: 0.2550 - acc: 0.9094 - val_loss: 0.2374 - val_acc: 0.9453
#
# Epoch 00034: val_loss improved from 0.24046 to 0.23737, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_6.hdf5
# Epoch 35/50
#  - 1s - loss: 0.1928 - acc: 0.9500 - val_loss: 0.3555 - val_acc: 0.8672
#
# Epoch 00035: val_loss did not improve from 0.23737
# Epoch 36/50
#  - 1s - loss: 0.3017 - acc: 0.9094 - val_loss: 0.4527 - val_acc: 0.8203
#
# Epoch 00036: val_loss did not improve from 0.23737
# Epoch 37/50
#  - 1s - loss: 0.2496 - acc: 0.9313 - val_loss: 0.7158 - val_acc: 0.6484
#
# Epoch 00037: val_loss did not improve from 0.23737
# Epoch 38/50
#  - 1s - loss: 0.2202 - acc: 0.9375 - val_loss: 0.5534 - val_acc: 0.7969
#
# Epoch 00038: val_loss did not improve from 0.23737
# Epoch 39/50
#  - 1s - loss: 0.2662 - acc: 0.9062 - val_loss: 0.8797 - val_acc: 0.5547
#
# Epoch 00039: val_loss did not improve from 0.23737
# Epoch 40/50
#  - 1s - loss: 0.2318 - acc: 0.9406 - val_loss: 0.2560 - val_acc: 0.8977
#
# Epoch 00040: val_loss did not improve from 0.23737
# Epoch 41/50
#  - 1s - loss: 0.2816 - acc: 0.9281 - val_loss: 0.4162 - val_acc: 0.8203
#
# Epoch 00041: val_loss did not improve from 0.23737
# Epoch 42/50
#  - 1s - loss: 0.2087 - acc: 0.9452 - val_loss: 0.2692 - val_acc: 0.9375
#
# Epoch 00042: val_loss did not improve from 0.23737
# Epoch 43/50
#  - 1s - loss: 0.3466 - acc: 0.8969 - val_loss: 0.6400 - val_acc: 0.6797
#
# Epoch 00043: val_loss did not improve from 0.23737
# Epoch 44/50
#  - 1s - loss: 0.2324 - acc: 0.9375 - val_loss: 0.4139 - val_acc: 0.8516
#
# Epoch 00044: val_loss did not improve from 0.23737
# Epoch 45/50
#  - 1s - loss: 0.2233 - acc: 0.9281 - val_loss: 0.5155 - val_acc: 0.8594
#
# Epoch 00045: val_loss did not improve from 0.23737
# Epoch 46/50
#  - 1s - loss: 0.2527 - acc: 0.9375 - val_loss: 0.3588 - val_acc: 0.8828
#
# Epoch 00046: val_loss did not improve from 0.23737
# Epoch 47/50
#  - 1s - loss: 0.2268 - acc: 0.9375 - val_loss: 0.2418 - val_acc: 0.9297
#
# Epoch 00047: val_loss did not improve from 0.23737
# Epoch 48/50
#  - 1s - loss: 0.2513 - acc: 0.9125 - val_loss: 0.2408 - val_acc: 0.9531
#
# Epoch 00048: val_loss did not improve from 0.23737
# Epoch 49/50
#  - 1s - loss: 0.1749 - acc: 0.9656 - val_loss: 0.5117 - val_acc: 0.8906
#
# Epoch 00049: val_loss did not improve from 0.23737
# Epoch 50/50
#  - 1s - loss: 0.1930 - acc: 0.9594 - val_loss: 0.4304 - val_acc: 0.8828
#
# Epoch 00050: val_loss did not improve from 0.23737

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 62.29%, AUC: 0.931, Accuracy: 81.66%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 7 tentativa - Test Precision: 24.27%, AUC: 0.949, Accuracy: 38.98%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Sem os **dropout**
# *   Função **Adadelta** para compilação
# *   **BatchNormalization** antes da ultima camada Dense

# %%
architecture = 'architecture_7'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adadelta

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 6s - loss: 0.6079 - acc: 0.7219 - val_loss: 1.0115 - val_acc: 0.6797
#
# Epoch 00001: val_loss improved from inf to 1.01150, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_7.hdf5
# Epoch 2/50
#  - 0s - loss: 0.2880 - acc: 0.9188 - val_loss: 0.7099 - val_acc: 0.8359
#
# Epoch 00002: val_loss improved from 1.01150 to 0.70993, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_7.hdf5
# Epoch 3/50
#  - 0s - loss: 0.3077 - acc: 0.8969 - val_loss: 0.4301 - val_acc: 0.8750
#
# Epoch 00003: val_loss improved from 0.70993 to 0.43011, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_7.hdf5
# Epoch 4/50
#  - 1s - loss: 0.2729 - acc: 0.9250 - val_loss: 0.5246 - val_acc: 0.8906
#
# Epoch 00004: val_loss did not improve from 0.43011
# Epoch 5/50
#  - 2s - loss: 0.1925 - acc: 0.9531 - val_loss: 0.3280 - val_acc: 0.9219
#
# Epoch 00005: val_loss improved from 0.43011 to 0.32803, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_7.hdf5
# Epoch 6/50
#  - 1s - loss: 0.3452 - acc: 0.9094 - val_loss: 0.4295 - val_acc: 0.9297
#
# Epoch 00006: val_loss did not improve from 0.32803
# Epoch 7/50
#  - 1s - loss: 0.2706 - acc: 0.9250 - val_loss: 1.0193 - val_acc: 0.6719
#
# Epoch 00007: val_loss did not improve from 0.32803
# Epoch 8/50
#  - 1s - loss: 0.2572 - acc: 0.9188 - val_loss: 0.1463 - val_acc: 0.9688
#
# Epoch 00008: val_loss improved from 0.32803 to 0.14625, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_7.hdf5
# Epoch 9/50
#  - 1s - loss: 0.2365 - acc: 0.9375 - val_loss: 0.4775 - val_acc: 0.8984
#
# Epoch 00009: val_loss did not improve from 0.14625
# Epoch 10/50
#  - 1s - loss: 0.2604 - acc: 0.9031 - val_loss: 0.4112 - val_acc: 0.9219
#
# Epoch 00010: val_loss did not improve from 0.14625
# Epoch 11/50
#  - 1s - loss: 0.3688 - acc: 0.8906 - val_loss: 0.6294 - val_acc: 0.7734
#
# Epoch 00011: val_loss did not improve from 0.14625
# Epoch 12/50
#  - 1s - loss: 0.2233 - acc: 0.9375 - val_loss: 0.5030 - val_acc: 0.8906
#
# Epoch 00012: val_loss did not improve from 0.14625
# Epoch 13/50
#  - 1s - loss: 0.2738 - acc: 0.9250 - val_loss: 0.8215 - val_acc: 0.7266
#
# Epoch 00013: val_loss did not improve from 0.14625
# Epoch 14/50
#  - 1s - loss: 0.2501 - acc: 0.9281 - val_loss: 0.5599 - val_acc: 0.8516
#
# Epoch 00014: val_loss did not improve from 0.14625
# Epoch 15/50
#  - 1s - loss: 0.2288 - acc: 0.9313 - val_loss: 0.7223 - val_acc: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.14625
# Epoch 16/50
#  - 1s - loss: 0.2689 - acc: 0.9188 - val_loss: 0.3266 - val_acc: 0.8984
#
# Epoch 00016: val_loss did not improve from 0.14625
# Epoch 17/50
#  - 1s - loss: 0.2014 - acc: 0.9562 - val_loss: 0.4990 - val_acc: 0.8906
#
# Epoch 00017: val_loss did not improve from 0.14625
# Epoch 18/50
#  - 1s - loss: 0.2108 - acc: 0.9290 - val_loss: 0.4257 - val_acc: 0.9375
#
# Epoch 00018: val_loss did not improve from 0.14625
# Epoch 19/50
#  - 1s - loss: 0.1939 - acc: 0.9281 - val_loss: 0.6223 - val_acc: 0.8359
#
# Epoch 00019: val_loss did not improve from 0.14625
# Epoch 20/50
#  - 1s - loss: 0.1565 - acc: 0.9562 - val_loss: 1.1091 - val_acc: 0.8409
#
# Epoch 00020: val_loss did not improve from 0.14625
# Epoch 21/50
#  - 1s - loss: 0.1622 - acc: 0.9688 - val_loss: 0.3272 - val_acc: 0.9219
#
# Epoch 00021: val_loss did not improve from 0.14625
# Epoch 22/50
#  - 1s - loss: 0.2778 - acc: 0.9125 - val_loss: 0.5964 - val_acc: 0.8828
#
# Epoch 00022: val_loss did not improve from 0.14625
# Epoch 23/50
#  - 1s - loss: 0.2022 - acc: 0.9719 - val_loss: 0.6145 - val_acc: 0.8516
#
# Epoch 00023: val_loss did not improve from 0.14625
# Epoch 24/50
#  - 1s - loss: 0.2736 - acc: 0.9188 - val_loss: 0.7455 - val_acc: 0.8516
#
# Epoch 00024: val_loss did not improve from 0.14625
# Epoch 25/50
#  - 1s - loss: 0.1863 - acc: 0.9594 - val_loss: 0.4433 - val_acc: 0.9141
#
# Epoch 00025: val_loss did not improve from 0.14625
# Epoch 26/50
#  - 1s - loss: 0.2455 - acc: 0.9313 - val_loss: 0.3951 - val_acc: 0.8750
#
# Epoch 00026: val_loss did not improve from 0.14625
# Epoch 27/50
#  - 1s - loss: 0.2610 - acc: 0.9250 - val_loss: 0.3375 - val_acc: 0.8984
#
# Epoch 00027: val_loss did not improve from 0.14625
# Epoch 28/50
#  - 1s - loss: 0.2382 - acc: 0.9313 - val_loss: 0.6064 - val_acc: 0.8906
#
# Epoch 00028: val_loss did not improve from 0.14625
# Epoch 29/50
#  - 1s - loss: 0.2203 - acc: 0.9188 - val_loss: 0.4165 - val_acc: 0.8828
#
# Epoch 00029: val_loss did not improve from 0.14625
# Epoch 30/50
#  - 1s - loss: 0.2317 - acc: 0.9437 - val_loss: 0.3614 - val_acc: 0.9219
#
# Epoch 00030: val_loss did not improve from 0.14625
# Epoch 31/50
#  - 1s - loss: 0.2508 - acc: 0.9375 - val_loss: 0.7310 - val_acc: 0.8438
#
# Epoch 00031: val_loss did not improve from 0.14625
# Epoch 32/50
#  - 1s - loss: 0.2412 - acc: 0.9188 - val_loss: 0.2131 - val_acc: 0.9297
#
# Epoch 00032: val_loss did not improve from 0.14625
# Epoch 33/50
#  - 1s - loss: 0.2058 - acc: 0.9437 - val_loss: 0.4601 - val_acc: 0.9219
#
# Epoch 00033: val_loss did not improve from 0.14625
# Epoch 34/50
#  - 1s - loss: 0.2612 - acc: 0.9469 - val_loss: 0.3624 - val_acc: 0.8828
#
# Epoch 00034: val_loss did not improve from 0.14625
# Epoch 35/50
#  - 1s - loss: 0.2784 - acc: 0.9344 - val_loss: 0.4286 - val_acc: 0.8594
#
# Epoch 00035: val_loss did not improve from 0.14625
# Epoch 36/50
#  - 1s - loss: 0.2523 - acc: 0.9156 - val_loss: 0.4158 - val_acc: 0.8594
#
# Epoch 00036: val_loss did not improve from 0.14625
# Epoch 37/50
#  - 1s - loss: 0.2485 - acc: 0.9281 - val_loss: 0.3963 - val_acc: 0.8516
#
# Epoch 00037: val_loss did not improve from 0.14625
# Epoch 38/50
#  - 1s - loss: 0.2251 - acc: 0.9344 - val_loss: 0.3749 - val_acc: 0.9205
#
# Epoch 00038: val_loss did not improve from 0.14625
# Epoch 39/50
#  - 1s - loss: 0.2277 - acc: 0.9250 - val_loss: 0.4951 - val_acc: 0.9062
#
# Epoch 00039: val_loss did not improve from 0.14625
# Epoch 40/50
#  - 1s - loss: 0.1892 - acc: 0.9469 - val_loss: 0.3484 - val_acc: 0.8906
#
# Epoch 00040: val_loss did not improve from 0.14625
# Epoch 41/50
#  - 1s - loss: 0.2395 - acc: 0.9437 - val_loss: 0.3977 - val_acc: 0.8828
#
# Epoch 00041: val_loss did not improve from 0.14625
# Epoch 42/50
#  - 1s - loss: 0.2519 - acc: 0.9313 - val_loss: 0.3605 - val_acc: 0.8438
#
# Epoch 00042: val_loss did not improve from 0.14625
# Epoch 43/50
#  - 1s - loss: 0.1882 - acc: 0.9406 - val_loss: 0.3771 - val_acc: 0.9141
#
# Epoch 00043: val_loss did not improve from 0.14625
# Epoch 44/50
#  - 1s - loss: 0.2080 - acc: 0.9375 - val_loss: 0.4009 - val_acc: 0.8750
#
# Epoch 00044: val_loss did not improve from 0.14625
# Epoch 45/50
#  - 1s - loss: 0.3877 - acc: 0.8871 - val_loss: 0.6615 - val_acc: 0.6797
#
# Epoch 00045: val_loss did not improve from 0.14625
# Epoch 46/50
#  - 1s - loss: 0.3298 - acc: 0.8875 - val_loss: 0.9480 - val_acc: 0.4766
#
# Epoch 00046: val_loss did not improve from 0.14625
# Epoch 47/50
#  - 1s - loss: 0.2705 - acc: 0.9250 - val_loss: 0.5865 - val_acc: 0.7188
#
# Epoch 00047: val_loss did not improve from 0.14625
# Epoch 48/50
#  - 1s - loss: 0.2092 - acc: 0.9281 - val_loss: 0.3393 - val_acc: 0.9375
#
# Epoch 00048: val_loss did not improve from 0.14625
# Epoch 49/50
#  - 1s - loss: 0.2797 - acc: 0.9156 - val_loss: 0.2626 - val_acc: 0.9531
#
# Epoch 00049: val_loss did not improve from 0.14625
# Epoch 50/50
#  - 1s - loss: 0.2151 - acc: 0.9250 - val_loss: 0.3024 - val_acc: 0.8906
#
# Epoch 00050: val_loss did not improve from 0.14625

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 24.27%, AUC: 0.949, Accuracy: 38.98%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 8 tentativa - Test Precision: 19.64%, AUC: 0.774, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Função **Adadelta** para compilação

# %%
architecture = 'architecture_8'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adadelta

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0.0), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 7s - loss: 3.8045 - acc: 0.5594 - val_loss: 1.0233 - val_acc: 0.6484
#
# Epoch 00001: val_loss improved from inf to 1.02333, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_8.hdf5
# Epoch 2/50
#  - 1s - loss: 3.7128 - acc: 0.5531 - val_loss: 2.9981 - val_acc: 0.5391
#
# Epoch 00002: val_loss did not improve from 1.02333
# Epoch 3/50
#  - 1s - loss: 1.6590 - acc: 0.7469 - val_loss: 0.1515 - val_acc: 0.9453
#
# Epoch 00003: val_loss improved from 1.02333 to 0.15153, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_8.hdf5
# Epoch 4/50
#  - 1s - loss: 0.4256 - acc: 0.8875 - val_loss: 0.4388 - val_acc: 0.9375
#
# Epoch 00004: val_loss did not improve from 0.15153
# Epoch 5/50
#  - 2s - loss: 0.5832 - acc: 0.8937 - val_loss: 0.5130 - val_acc: 0.9062
#
# Epoch 00005: val_loss did not improve from 0.15153
# Epoch 6/50
#  - 1s - loss: 0.9463 - acc: 0.8688 - val_loss: 1.7022 - val_acc: 0.6719
#
# Epoch 00006: val_loss did not improve from 0.15153
# Epoch 7/50
#  - 1s - loss: 0.6851 - acc: 0.8844 - val_loss: 0.6716 - val_acc: 0.9062
#
# Epoch 00007: val_loss did not improve from 0.15153
# Epoch 8/50
#  - 1s - loss: 0.9873 - acc: 0.8469 - val_loss: 0.4150 - val_acc: 0.9219
#
# Epoch 00008: val_loss did not improve from 0.15153
# Epoch 9/50
#  - 1s - loss: 0.4600 - acc: 0.9125 - val_loss: 0.6502 - val_acc: 0.9062
#
# Epoch 00009: val_loss did not improve from 0.15153
# Epoch 10/50
#  - 1s - loss: 0.3277 - acc: 0.9281 - val_loss: 1.4795 - val_acc: 0.7969
#
# Epoch 00010: val_loss did not improve from 0.15153
# Epoch 11/50
#  - 1s - loss: 0.3512 - acc: 0.9125 - val_loss: 0.4813 - val_acc: 0.9062
#
# Epoch 00011: val_loss did not improve from 0.15153
# Epoch 12/50
#  - 1s - loss: 0.4152 - acc: 0.9188 - val_loss: 0.5903 - val_acc: 0.9219
#
# Epoch 00012: val_loss did not improve from 0.15153
# Epoch 13/50
#  - 1s - loss: 0.5132 - acc: 0.9219 - val_loss: 0.3993 - val_acc: 0.9531
#
# Epoch 00013: val_loss did not improve from 0.15153
# Epoch 14/50
#  - 1s - loss: 0.4647 - acc: 0.9000 - val_loss: 0.5359 - val_acc: 0.9062
#
# Epoch 00014: val_loss did not improve from 0.15153
# Epoch 15/50
#  - 1s - loss: 0.6427 - acc: 0.8594 - val_loss: 0.2857 - val_acc: 0.9141
#
# Epoch 00015: val_loss did not improve from 0.15153
# Epoch 16/50
#  - 1s - loss: 0.2581 - acc: 0.9188 - val_loss: 0.4458 - val_acc: 0.8906
#
# Epoch 00016: val_loss did not improve from 0.15153
# Epoch 17/50
#  - 1s - loss: 0.3629 - acc: 0.9125 - val_loss: 0.3953 - val_acc: 0.8594
#
# Epoch 00017: val_loss did not improve from 0.15153
# Epoch 18/50
#  - 1s - loss: 0.3824 - acc: 0.8812 - val_loss: 0.5902 - val_acc: 0.7500
#
# Epoch 00018: val_loss did not improve from 0.15153
# Epoch 19/50
#  - 1s - loss: 0.3764 - acc: 0.9031 - val_loss: 0.3040 - val_acc: 0.9062
#
# Epoch 00019: val_loss did not improve from 0.15153
# Epoch 20/50
#  - 1s - loss: 0.2709 - acc: 0.9313 - val_loss: 0.1994 - val_acc: 0.9453
#
# Epoch 00020: val_loss did not improve from 0.15153
# Epoch 21/50
#  - 1s - loss: 0.1908 - acc: 0.9548 - val_loss: 0.2974 - val_acc: 0.9297
#
# Epoch 00021: val_loss did not improve from 0.15153
# Epoch 22/50
#  - 1s - loss: 0.2693 - acc: 0.9375 - val_loss: 0.5010 - val_acc: 0.8672
#
# Epoch 00022: val_loss did not improve from 0.15153
# Epoch 23/50
#  - 1s - loss: 0.3045 - acc: 0.9250 - val_loss: 0.2406 - val_acc: 0.9375
#
# Epoch 00023: val_loss did not improve from 0.15153
# Epoch 24/50
#  - 1s - loss: 0.3417 - acc: 0.9188 - val_loss: 0.1815 - val_acc: 0.9531
#
# Epoch 00024: val_loss did not improve from 0.15153
# Epoch 25/50
#  - 1s - loss: 0.3280 - acc: 0.9156 - val_loss: 0.6323 - val_acc: 0.8047
#
# Epoch 00025: val_loss did not improve from 0.15153
# Epoch 26/50
#  - 1s - loss: 0.2638 - acc: 0.9437 - val_loss: 0.3494 - val_acc: 0.9141
#
# Epoch 00026: val_loss did not improve from 0.15153
# Epoch 27/50
#  - 1s - loss: 0.3691 - acc: 0.8844 - val_loss: 0.3203 - val_acc: 0.8984
#
# Epoch 00027: val_loss did not improve from 0.15153
# Epoch 28/50
#  - 1s - loss: 0.2467 - acc: 0.9437 - val_loss: 0.4216 - val_acc: 0.8750
#
# Epoch 00028: val_loss did not improve from 0.15153
# Epoch 29/50
#  - 1s - loss: 0.2558 - acc: 0.9406 - val_loss: 0.4300 - val_acc: 0.8906
#
# Epoch 00029: val_loss did not improve from 0.15153
# Epoch 30/50
#  - 1s - loss: 0.2237 - acc: 0.9344 - val_loss: 0.4239 - val_acc: 0.8828
#
# Epoch 00030: val_loss did not improve from 0.15153
# Epoch 31/50
#  - 1s - loss: 0.2905 - acc: 0.9250 - val_loss: 0.5420 - val_acc: 0.8438
#
# Epoch 00031: val_loss did not improve from 0.15153
# Epoch 32/50
#  - 1s - loss: 0.3416 - acc: 0.9156 - val_loss: 0.2306 - val_acc: 0.9453
#
# Epoch 00032: val_loss did not improve from 0.15153
# Epoch 33/50
#  - 1s - loss: 0.1728 - acc: 0.9625 - val_loss: 0.2690 - val_acc: 0.9375
#
# Epoch 00033: val_loss did not improve from 0.15153
# Epoch 34/50
#  - 1s - loss: 0.2506 - acc: 0.9500 - val_loss: 0.3375 - val_acc: 0.8828
#
# Epoch 00034: val_loss did not improve from 0.15153
# Epoch 35/50
#  - 1s - loss: 0.2917 - acc: 0.9250 - val_loss: 0.3383 - val_acc: 0.8636
#
# Epoch 00035: val_loss did not improve from 0.15153
# Epoch 36/50
#  - 1s - loss: 0.3137 - acc: 0.9156 - val_loss: 0.2822 - val_acc: 0.9219
#
# Epoch 00036: val_loss did not improve from 0.15153
# Epoch 37/50
#  - 1s - loss: 0.3146 - acc: 0.9031 - val_loss: 0.3326 - val_acc: 0.8984
#
# Epoch 00037: val_loss did not improve from 0.15153
# Epoch 38/50
#  - 1s - loss: 0.2120 - acc: 0.9531 - val_loss: 0.3352 - val_acc: 0.9375
#
# Epoch 00038: val_loss did not improve from 0.15153
# Epoch 39/50
#  - 1s - loss: 0.2927 - acc: 0.9156 - val_loss: 0.2860 - val_acc: 0.9062
#
# Epoch 00039: val_loss did not improve from 0.15153
# Epoch 40/50
#  - 1s - loss: 0.2725 - acc: 0.9250 - val_loss: 0.2016 - val_acc: 0.9688
#
# Epoch 00040: val_loss did not improve from 0.15153
# Epoch 41/50
#  - 1s - loss: 0.3639 - acc: 0.9094 - val_loss: 0.4281 - val_acc: 0.8750
#
# Epoch 00041: val_loss did not improve from 0.15153
# Epoch 42/50
#  - 1s - loss: 0.2045 - acc: 0.9344 - val_loss: 0.2774 - val_acc: 0.8984
#
# Epoch 00042: val_loss did not improve from 0.15153
# Epoch 43/50
#  - 1s - loss: 0.2669 - acc: 0.9375 - val_loss: 0.2539 - val_acc: 0.9062
#
# Epoch 00043: val_loss did not improve from 0.15153
# Epoch 44/50
#  - 1s - loss: 0.4092 - acc: 0.8750 - val_loss: 0.7112 - val_acc: 0.5859
#
# Epoch 00044: val_loss did not improve from 0.15153
# Epoch 45/50
#  - 1s - loss: 0.4296 - acc: 0.8719 - val_loss: 0.8457 - val_acc: 0.7109
#
# Epoch 00045: val_loss did not improve from 0.15153
# Epoch 46/50
#  - 1s - loss: 0.3043 - acc: 0.9188 - val_loss: 1.2969 - val_acc: 0.4375
#
# Epoch 00046: val_loss did not improve from 0.15153
# Epoch 47/50
#  - 1s - loss: 0.2603 - acc: 0.9250 - val_loss: 1.2138 - val_acc: 0.4922
#
# Epoch 00047: val_loss did not improve from 0.15153
# Epoch 48/50
#  - 1s - loss: 0.2315 - acc: 0.9355 - val_loss: 0.5004 - val_acc: 0.8203
#
# Epoch 00048: val_loss did not improve from 0.15153
# Epoch 49/50
#  - 1s - loss: 0.2240 - acc: 0.9406 - val_loss: 0.4383 - val_acc: 0.8438
#
# Epoch 00049: val_loss did not improve from 0.15153
# Epoch 50/50
#  - 1s - loss: 0.3390 - acc: 0.9094 - val_loss: 0.4061 - val_acc: 0.8750
#
# Epoch 00050: val_loss did not improve from 0.15153

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.774, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 9 tentativa - Test Precision: 19.64%, AUC: 0.056, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Função **SGD** para compilação

# %%
architecture = 'architecture_9'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(SGD(lr=0.03, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 7s - loss: 6.4104 - acc: 0.5187 - val_loss: 8.3018 - val_acc: 0.4844
#
# Epoch 00001: val_loss improved from inf to 8.30179, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 2/50
#  - 1s - loss: 7.3067 - acc: 0.5156 - val_loss: 9.8092 - val_acc: 0.3906
#
# Epoch 00002: val_loss did not improve from 8.30179
# Epoch 3/50
#  - 0s - loss: 8.8574 - acc: 0.4500 - val_loss: 8.5568 - val_acc: 0.4688
#
# Epoch 00003: val_loss did not improve from 8.30179
# Epoch 4/50
#  - 1s - loss: 9.3583 - acc: 0.4188 - val_loss: 7.5549 - val_acc: 0.5312
#
# Epoch 00004: val_loss improved from 8.30179 to 7.55492, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 5/50
#  - 2s - loss: 7.9557 - acc: 0.5062 - val_loss: 7.0540 - val_acc: 0.5625
#
# Epoch 00005: val_loss improved from 7.55492 to 7.05398, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 6/50
#  - 1s - loss: 7.7553 - acc: 0.5187 - val_loss: 7.0540 - val_acc: 0.5625
#
# Epoch 00006: val_loss improved from 7.05398 to 7.05397, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 7/50
#  - 1s - loss: 8.6570 - acc: 0.4625 - val_loss: 8.8073 - val_acc: 0.4531
#
# Epoch 00007: val_loss did not improve from 7.05397
# Epoch 8/50
#  - 1s - loss: 6.8499 - acc: 0.5750 - val_loss: 7.8054 - val_acc: 0.5156
#
# Epoch 00008: val_loss did not improve from 7.05397
# Epoch 9/50
#  - 1s - loss: 8.6419 - acc: 0.4625 - val_loss: 7.0540 - val_acc: 0.5625
#
# Epoch 00009: val_loss improved from 7.05397 to 7.05396, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 10/50
#  - 1s - loss: 7.8555 - acc: 0.5125 - val_loss: 8.5568 - val_acc: 0.4688
#
# Epoch 00010: val_loss did not improve from 7.05396
# Epoch 11/50
#  - 1s - loss: 7.8549 - acc: 0.5125 - val_loss: 8.3063 - val_acc: 0.4844
#
# Epoch 00011: val_loss did not improve from 7.05396
# Epoch 12/50
#  - 1s - loss: 7.2147 - acc: 0.5094 - val_loss: 4.4935 - val_acc: 0.6797
#
# Epoch 00012: val_loss improved from 7.05396 to 4.49350, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 13/50
#  - 1s - loss: 5.9712 - acc: 0.5750 - val_loss: 5.5082 - val_acc: 0.6328
#
# Epoch 00013: val_loss did not improve from 4.49350
# Epoch 14/50
#  - 1s - loss: 4.0061 - acc: 0.7000 - val_loss: 0.5405 - val_acc: 0.9141
#
# Epoch 00014: val_loss improved from 4.49350 to 0.54053, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 15/50
#  - 1s - loss: 0.8502 - acc: 0.8344 - val_loss: 2.4284 - val_acc: 0.6705
#
# Epoch 00015: val_loss did not improve from 0.54053
# Epoch 16/50
#  - 1s - loss: 1.2676 - acc: 0.8125 - val_loss: 2.1693 - val_acc: 0.7734
#
# Epoch 00016: val_loss did not improve from 0.54053
# Epoch 17/50
#  - 1s - loss: 0.4213 - acc: 0.9344 - val_loss: 2.6563 - val_acc: 0.6406
#
# Epoch 00017: val_loss did not improve from 0.54053
# Epoch 18/50
#  - 1s - loss: 0.2500 - acc: 0.9469 - val_loss: 1.2539 - val_acc: 0.7969
#
# Epoch 00018: val_loss did not improve from 0.54053
# Epoch 19/50
#  - 1s - loss: 0.3585 - acc: 0.9125 - val_loss: 0.6459 - val_acc: 0.7266
#
# Epoch 00019: val_loss did not improve from 0.54053
# Epoch 20/50
#  - 1s - loss: 0.1958 - acc: 0.9500 - val_loss: 0.3320 - val_acc: 0.9297
#
# Epoch 00020: val_loss improved from 0.54053 to 0.33204, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 21/50
#  - 1s - loss: 0.3328 - acc: 0.8969 - val_loss: 0.2839 - val_acc: 0.9141
#
# Epoch 00021: val_loss improved from 0.33204 to 0.28390, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 22/50
#  - 1s - loss: 0.2677 - acc: 0.9031 - val_loss: 0.3015 - val_acc: 0.9219
#
# Epoch 00022: val_loss did not improve from 0.28390
# Epoch 23/50
#  - 1s - loss: 0.2176 - acc: 0.9500 - val_loss: 0.1559 - val_acc: 0.9688
#
# Epoch 00023: val_loss improved from 0.28390 to 0.15591, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 24/50
#  - 1s - loss: 0.2709 - acc: 0.9323 - val_loss: 0.4823 - val_acc: 0.8594
#
# Epoch 00024: val_loss did not improve from 0.15591
# Epoch 25/50
#  - 1s - loss: 0.3084 - acc: 0.9406 - val_loss: 0.2440 - val_acc: 0.9531
#
# Epoch 00025: val_loss did not improve from 0.15591
# Epoch 26/50
#  - 1s - loss: 0.2463 - acc: 0.9469 - val_loss: 0.5410 - val_acc: 0.8828
#
# Epoch 00026: val_loss did not improve from 0.15591
# Epoch 27/50
#  - 1s - loss: 0.2397 - acc: 0.9344 - val_loss: 0.3567 - val_acc: 0.9062
#
# Epoch 00027: val_loss did not improve from 0.15591
# Epoch 28/50
#  - 1s - loss: 0.2692 - acc: 0.9250 - val_loss: 0.4789 - val_acc: 0.8672
#
# Epoch 00028: val_loss did not improve from 0.15591
# Epoch 29/50
#  - 1s - loss: 0.2307 - acc: 0.9406 - val_loss: 0.5747 - val_acc: 0.8516
#
# Epoch 00029: val_loss did not improve from 0.15591
# Epoch 30/50
#  - 1s - loss: 0.2528 - acc: 0.9437 - val_loss: 0.3972 - val_acc: 0.9062
#
# Epoch 00030: val_loss did not improve from 0.15591
# Epoch 31/50
#  - 1s - loss: 0.2767 - acc: 0.9313 - val_loss: 0.2330 - val_acc: 0.9375
#
# Epoch 00031: val_loss did not improve from 0.15591
# Epoch 32/50
#  - 1s - loss: 0.2312 - acc: 0.9406 - val_loss: 0.3011 - val_acc: 0.9453
#
# Epoch 00032: val_loss did not improve from 0.15591
# Epoch 33/50
#  - 1s - loss: 0.2544 - acc: 0.9531 - val_loss: 0.2238 - val_acc: 0.8864
#
# Epoch 00033: val_loss did not improve from 0.15591
# Epoch 34/50
#  - 1s - loss: 0.2882 - acc: 0.9313 - val_loss: 0.5488 - val_acc: 0.8672
#
# Epoch 00034: val_loss did not improve from 0.15591
# Epoch 35/50
#  - 1s - loss: 0.2624 - acc: 0.9250 - val_loss: 0.1618 - val_acc: 0.9375
#
# Epoch 00035: val_loss did not improve from 0.15591
# Epoch 36/50
#  - 1s - loss: 0.2314 - acc: 0.9375 - val_loss: 0.1375 - val_acc: 0.9766
#
# Epoch 00036: val_loss improved from 0.15591 to 0.13751, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_9.hdf5
# Epoch 37/50
#  - 1s - loss: 0.2877 - acc: 0.9406 - val_loss: 0.3898 - val_acc: 0.8906
#
# Epoch 00037: val_loss did not improve from 0.13751
# Epoch 38/50
#  - 1s - loss: 0.2404 - acc: 0.9469 - val_loss: 0.4991 - val_acc: 0.8672
#
# Epoch 00038: val_loss did not improve from 0.13751
# Epoch 39/50
#  - 1s - loss: 0.2274 - acc: 0.9562 - val_loss: 0.1937 - val_acc: 0.9453
#
# Epoch 00039: val_loss did not improve from 0.13751
# Epoch 40/50
#  - 1s - loss: 0.2917 - acc: 0.9313 - val_loss: 0.2558 - val_acc: 0.9062
#
# Epoch 00040: val_loss did not improve from 0.13751
# Epoch 41/50
#  - 1s - loss: 0.3565 - acc: 0.9188 - val_loss: 0.2188 - val_acc: 0.9609
#
# Epoch 00041: val_loss did not improve from 0.13751
# Epoch 42/50
#  - 1s - loss: 0.2055 - acc: 0.9656 - val_loss: 0.2720 - val_acc: 0.9219
#
# Epoch 00042: val_loss did not improve from 0.13751
# Epoch 43/50
#  - 1s - loss: 0.2909 - acc: 0.9344 - val_loss: 0.2582 - val_acc: 0.9375
#
# Epoch 00043: val_loss did not improve from 0.13751
# Epoch 44/50
#  - 1s - loss: 0.2867 - acc: 0.9375 - val_loss: 0.4145 - val_acc: 0.8906
#
# Epoch 00044: val_loss did not improve from 0.13751
# Epoch 45/50
#  - 1s - loss: 0.2567 - acc: 0.9313 - val_loss: 0.4206 - val_acc: 0.8828
#
# Epoch 00045: val_loss did not improve from 0.13751
# Epoch 46/50
#  - 1s - loss: 0.3273 - acc: 0.8969 - val_loss: 0.3633 - val_acc: 0.9062
#
# Epoch 00046: val_loss did not improve from 0.13751
# Epoch 47/50
#  - 1s - loss: 0.2521 - acc: 0.9313 - val_loss: 0.5232 - val_acc: 0.8516
#
# Epoch 00047: val_loss did not improve from 0.13751
# Epoch 48/50
#  - 1s - loss: 0.1966 - acc: 0.9531 - val_loss: 0.3224 - val_acc: 0.9297
#
# Epoch 00048: val_loss did not improve from 0.13751
# Epoch 49/50
#  - 1s - loss: 0.2248 - acc: 0.9313 - val_loss: 0.4898 - val_acc: 0.8516
#
# Epoch 00049: val_loss did not improve from 0.13751
# Epoch 50/50
#  - 1s - loss: 0.3212 - acc: 0.9094 - val_loss: 0.2645 - val_acc: 0.9545
#
# Epoch 00050: val_loss did not improve from 0.13751

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.056, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 10 tentativa - Test Precision: 19.64%, AUC: 0.286, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Função **adam** para compilação
# *   Adicionado mais 2 camadas convolutivas

# %%
architecture = 'architecture_10'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(96, (3, 3),activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(96, (3, 3),activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 8s - loss: 2.7805 - acc: 0.4968 - val_loss: 0.6870 - val_acc: 0.6016
#
# Epoch 00001: val_loss improved from inf to 0.68701, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 2/50
#  - 1s - loss: 1.5962 - acc: 0.6000 - val_loss: 0.8249 - val_acc: 0.7422
#
# Epoch 00002: val_loss did not improve from 0.68701
# Epoch 3/50
#  - 1s - loss: 0.9959 - acc: 0.7000 - val_loss: 0.7984 - val_acc: 0.6562
#
# Epoch 00003: val_loss did not improve from 0.68701
# Epoch 4/50
#  - 1s - loss: 0.8996 - acc: 0.7406 - val_loss: 0.5055 - val_acc: 0.8281
#
# Epoch 00004: val_loss improved from 0.68701 to 0.50546, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 5/50
#  - 2s - loss: 0.6033 - acc: 0.8312 - val_loss: 0.7773 - val_acc: 0.8281
#
# Epoch 00005: val_loss did not improve from 0.50546
# Epoch 6/50
#  - 1s - loss: 0.3891 - acc: 0.9031 - val_loss: 0.5271 - val_acc: 0.8828
#
# Epoch 00006: val_loss did not improve from 0.50546
# Epoch 7/50
#  - 1s - loss: 0.4106 - acc: 0.9000 - val_loss: 0.6439 - val_acc: 0.8516
#
# Epoch 00007: val_loss did not improve from 0.50546
# Epoch 8/50
#  - 1s - loss: 0.2872 - acc: 0.9469 - val_loss: 0.5480 - val_acc: 0.8828
#
# Epoch 00008: val_loss did not improve from 0.50546
# Epoch 9/50
#  - 1s - loss: 0.6116 - acc: 0.8656 - val_loss: 0.4192 - val_acc: 0.9062
#
# Epoch 00009: val_loss improved from 0.50546 to 0.41917, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 10/50
#  - 1s - loss: 0.4754 - acc: 0.8812 - val_loss: 0.9118 - val_acc: 0.8125
#
# Epoch 00010: val_loss did not improve from 0.41917
# Epoch 11/50
#  - 1s - loss: 0.3980 - acc: 0.8937 - val_loss: 0.6684 - val_acc: 0.7969
#
# Epoch 00011: val_loss did not improve from 0.41917
# Epoch 12/50
#  - 1s - loss: 0.3756 - acc: 0.8625 - val_loss: 0.4599 - val_acc: 0.8750
#
# Epoch 00012: val_loss did not improve from 0.41917
# Epoch 13/50
#  - 1s - loss: 0.3299 - acc: 0.8937 - val_loss: 0.3862 - val_acc: 0.8636
#
# Epoch 00013: val_loss improved from 0.41917 to 0.38620, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 14/50
#  - 1s - loss: 0.3475 - acc: 0.9094 - val_loss: 0.3560 - val_acc: 0.8984
#
# Epoch 00014: val_loss improved from 0.38620 to 0.35602, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 15/50
#  - 1s - loss: 0.2654 - acc: 0.9437 - val_loss: 0.5011 - val_acc: 0.8906
#
# Epoch 00015: val_loss did not improve from 0.35602
# Epoch 16/50
#  - 1s - loss: 0.3129 - acc: 0.9125 - val_loss: 0.4290 - val_acc: 0.8672
#
# Epoch 00016: val_loss did not improve from 0.35602
# Epoch 17/50
#  - 1s - loss: 0.3733 - acc: 0.9313 - val_loss: 0.4424 - val_acc: 0.8984
#
# Epoch 00017: val_loss did not improve from 0.35602
# Epoch 18/50
#  - 1s - loss: 0.2006 - acc: 0.9500 - val_loss: 0.6398 - val_acc: 0.8594
#
# Epoch 00018: val_loss did not improve from 0.35602
# Epoch 19/50
#  - 1s - loss: 0.2665 - acc: 0.9344 - val_loss: 0.4498 - val_acc: 0.8906
#
# Epoch 00019: val_loss did not improve from 0.35602
# Epoch 20/50
#  - 1s - loss: 0.4040 - acc: 0.8812 - val_loss: 0.4816 - val_acc: 0.8438
#
# Epoch 00020: val_loss did not improve from 0.35602
# Epoch 21/50
#  - 1s - loss: 0.3721 - acc: 0.9094 - val_loss: 0.4086 - val_acc: 0.8672
#
# Epoch 00021: val_loss did not improve from 0.35602
# Epoch 22/50
#  - 1s - loss: 0.3627 - acc: 0.9031 - val_loss: 0.3612 - val_acc: 0.9297
#
# Epoch 00022: val_loss did not improve from 0.35602
# Epoch 23/50
#  - 1s - loss: 0.3047 - acc: 0.9250 - val_loss: 0.3571 - val_acc: 0.9141
#
# Epoch 00023: val_loss did not improve from 0.35602
# Epoch 24/50
#  - 1s - loss: 0.4092 - acc: 0.8750 - val_loss: 0.3104 - val_acc: 0.9062
#
# Epoch 00024: val_loss improved from 0.35602 to 0.31037, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 25/50
#  - 1s - loss: 0.2374 - acc: 0.9313 - val_loss: 0.3742 - val_acc: 0.9219
#
# Epoch 00025: val_loss did not improve from 0.31037
# Epoch 26/50
#  - 1s - loss: 0.2959 - acc: 0.9500 - val_loss: 0.2211 - val_acc: 0.9453
#
# Epoch 00026: val_loss improved from 0.31037 to 0.22110, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 27/50
#  - 1s - loss: 0.2403 - acc: 0.9484 - val_loss: 0.3270 - val_acc: 0.9062
#
# Epoch 00027: val_loss did not improve from 0.22110
# Epoch 28/50
#  - 1s - loss: 0.3334 - acc: 0.9250 - val_loss: 0.2305 - val_acc: 0.9531
#
# Epoch 00028: val_loss did not improve from 0.22110
# Epoch 29/50
#  - 1s - loss: 0.3314 - acc: 0.9000 - val_loss: 0.4329 - val_acc: 0.8594
#
# Epoch 00029: val_loss did not improve from 0.22110
# Epoch 30/50
#  - 1s - loss: 0.2670 - acc: 0.9219 - val_loss: 0.3592 - val_acc: 0.8864
#
# Epoch 00030: val_loss did not improve from 0.22110
# Epoch 31/50
#  - 1s - loss: 0.2073 - acc: 0.9500 - val_loss: 0.4151 - val_acc: 0.9062
#
# Epoch 00031: val_loss did not improve from 0.22110
# Epoch 32/50
#  - 1s - loss: 0.2727 - acc: 0.9375 - val_loss: 0.4104 - val_acc: 0.8906
#
# Epoch 00032: val_loss did not improve from 0.22110
# Epoch 33/50
#  - 1s - loss: 0.3914 - acc: 0.8812 - val_loss: 0.3000 - val_acc: 0.9219
#
# Epoch 00033: val_loss did not improve from 0.22110
# Epoch 34/50
#  - 1s - loss: 0.2584 - acc: 0.9437 - val_loss: 0.3214 - val_acc: 0.9219
#
# Epoch 00034: val_loss did not improve from 0.22110
# Epoch 35/50
#  - 1s - loss: 0.3153 - acc: 0.9281 - val_loss: 0.1756 - val_acc: 0.9609
#
# Epoch 00035: val_loss improved from 0.22110 to 0.17562, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_10.hdf5
# Epoch 36/50
#  - 1s - loss: 0.2200 - acc: 0.9594 - val_loss: 0.2608 - val_acc: 0.9531
#
# Epoch 00036: val_loss did not improve from 0.17562
# Epoch 37/50
#  - 1s - loss: 0.2520 - acc: 0.9250 - val_loss: 0.2805 - val_acc: 0.9062
#
# Epoch 00037: val_loss did not improve from 0.17562
# Epoch 38/50
#  - 1s - loss: 0.2333 - acc: 0.9281 - val_loss: 0.3599 - val_acc: 0.9219
#
# Epoch 00038: val_loss did not improve from 0.17562
# Epoch 39/50
#  - 2s - loss: 0.3107 - acc: 0.9094 - val_loss: 0.4402 - val_acc: 0.8672
#
# Epoch 00039: val_loss did not improve from 0.17562
# Epoch 40/50
#  - 1s - loss: 0.1918 - acc: 0.9531 - val_loss: 0.2873 - val_acc: 0.9375
#
# Epoch 00040: val_loss did not improve from 0.17562
# Epoch 41/50
#  - 1s - loss: 0.2454 - acc: 0.9281 - val_loss: 0.3703 - val_acc: 0.8906
#
# Epoch 00041: val_loss did not improve from 0.17562
# Epoch 42/50
#  - 1s - loss: 0.2218 - acc: 0.9500 - val_loss: 0.5099 - val_acc: 0.8281
#
# Epoch 00042: val_loss did not improve from 0.17562
# Epoch 43/50
#  - 1s - loss: 0.2447 - acc: 0.9344 - val_loss: 0.4412 - val_acc: 0.8828
#
# Epoch 00043: val_loss did not improve from 0.17562
# Epoch 44/50
#  - 1s - loss: 0.4652 - acc: 0.8875 - val_loss: 0.3453 - val_acc: 0.8828
#
# Epoch 00044: val_loss did not improve from 0.17562
# Epoch 45/50
#  - 1s - loss: 0.2069 - acc: 0.9656 - val_loss: 0.4140 - val_acc: 0.8359
#
# Epoch 00045: val_loss did not improve from 0.17562
# Epoch 46/50
#  - 1s - loss: 0.3911 - acc: 0.8969 - val_loss: 0.4827 - val_acc: 0.8906
#
# Epoch 00046: val_loss did not improve from 0.17562
# Epoch 47/50
#  - 1s - loss: 0.2098 - acc: 0.9531 - val_loss: 0.4670 - val_acc: 0.8516
#
# Epoch 00047: val_loss did not improve from 0.17562
# Epoch 48/50
#  - 1s - loss: 0.2584 - acc: 0.9250 - val_loss: 0.3784 - val_acc: 0.8182
#
# Epoch 00048: val_loss did not improve from 0.17562
# Epoch 49/50
#  - 1s - loss: 0.3520 - acc: 0.9219 - val_loss: 0.2202 - val_acc: 0.9609
#
# Epoch 00049: val_loss did not improve from 0.17562
# Epoch 50/50
#  - 1s - loss: 0.1949 - acc: 0.9562 - val_loss: 0.4707 - val_acc: 0.8906
#
# Epoch 00050: val_loss did not improve from 0.17562

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.286, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 11 tentativa - Test Precision: 19.64%, AUC: 0.214, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do **Lucas Valentim**
#
# *   Função **SGD** para compilação
# *   Adicionado mais 2 camadas convolutivas

# %%
architecture = 'architecture_11'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4), 
                 input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(96, (3, 3),activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(Conv2D(96, (3, 3),activation='relu', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1), kernel_regularizer=l2(1e-4)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu', kernel_regularizer=l2(1e-4)))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid', kernel_regularizer=l2(1e-4)))

# %%
model.compile(SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 8s - loss: 4.5294 - acc: 0.4594 - val_loss: 2.7486 - val_acc: 0.5000
#
# Epoch 00001: val_loss improved from inf to 2.74856, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 2/50
#  - 1s - loss: 2.4938 - acc: 0.5469 - val_loss: 0.7044 - val_acc: 0.5391
#
# Epoch 00002: val_loss improved from 2.74856 to 0.70443, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 3/50
#  - 1s - loss: 1.0446 - acc: 0.6281 - val_loss: 0.7947 - val_acc: 0.5234
#
# Epoch 00003: val_loss did not improve from 0.70443
# Epoch 4/50
#  - 0s - loss: 1.0872 - acc: 0.5903 - val_loss: 0.7459 - val_acc: 0.5078
#
# Epoch 00004: val_loss did not improve from 0.70443
# Epoch 5/50
#  - 2s - loss: 0.7770 - acc: 0.6937 - val_loss: 0.6712 - val_acc: 0.5859
#
# Epoch 00005: val_loss improved from 0.70443 to 0.67121, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 6/50
#  - 1s - loss: 0.5664 - acc: 0.7625 - val_loss: 0.8268 - val_acc: 0.6641
#
# Epoch 00006: val_loss did not improve from 0.67121
# Epoch 7/50
#  - 1s - loss: 0.4497 - acc: 0.8656 - val_loss: 0.8011 - val_acc: 0.6719
#
# Epoch 00007: val_loss did not improve from 0.67121
# Epoch 8/50
#  - 1s - loss: 0.4420 - acc: 0.8438 - val_loss: 0.5443 - val_acc: 0.7266
#
# Epoch 00008: val_loss improved from 0.67121 to 0.54427, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 9/50
#  - 1s - loss: 0.4493 - acc: 0.8438 - val_loss: 0.4499 - val_acc: 0.8672
#
# Epoch 00009: val_loss improved from 0.54427 to 0.44992, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 10/50
#  - 1s - loss: 0.4984 - acc: 0.8625 - val_loss: 0.3438 - val_acc: 0.8977
#
# Epoch 00010: val_loss improved from 0.44992 to 0.34383, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 11/50
#  - 1s - loss: 0.3902 - acc: 0.8625 - val_loss: 0.3810 - val_acc: 0.9375
#
# Epoch 00011: val_loss did not improve from 0.34383
# Epoch 12/50
#  - 1s - loss: 0.3549 - acc: 0.8812 - val_loss: 0.2930 - val_acc: 0.9297
#
# Epoch 00012: val_loss improved from 0.34383 to 0.29299, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 13/50
#  - 1s - loss: 0.3164 - acc: 0.9156 - val_loss: 0.5861 - val_acc: 0.8203
#
# Epoch 00013: val_loss did not improve from 0.29299
# Epoch 14/50
#  - 1s - loss: 0.2888 - acc: 0.9188 - val_loss: 0.5546 - val_acc: 0.8281
#
# Epoch 00014: val_loss did not improve from 0.29299
# Epoch 15/50
#  - 1s - loss: 0.4139 - acc: 0.8781 - val_loss: 0.4876 - val_acc: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.29299
# Epoch 16/50
#  - 1s - loss: 0.2840 - acc: 0.9094 - val_loss: 0.4147 - val_acc: 0.8594
#
# Epoch 00016: val_loss did not improve from 0.29299
# Epoch 17/50
#  - 1s - loss: 0.3275 - acc: 0.9219 - val_loss: 0.4394 - val_acc: 0.8984
#
# Epoch 00017: val_loss did not improve from 0.29299
# Epoch 18/50
#  - 1s - loss: 0.3701 - acc: 0.8875 - val_loss: 0.4455 - val_acc: 0.8438
#
# Epoch 00018: val_loss did not improve from 0.29299
# Epoch 19/50
#  - 1s - loss: 0.2718 - acc: 0.9344 - val_loss: 0.4782 - val_acc: 0.8594
#
# Epoch 00019: val_loss did not improve from 0.29299
# Epoch 20/50
#  - 1s - loss: 0.3585 - acc: 0.9156 - val_loss: 0.4002 - val_acc: 0.9297
#
# Epoch 00020: val_loss did not improve from 0.29299
# Epoch 21/50
#  - 1s - loss: 0.4207 - acc: 0.8812 - val_loss: 0.4257 - val_acc: 0.8438
#
# Epoch 00021: val_loss did not improve from 0.29299
# Epoch 22/50
#  - 1s - loss: 0.3849 - acc: 0.8812 - val_loss: 0.6431 - val_acc: 0.7500
#
# Epoch 00022: val_loss did not improve from 0.29299
# Epoch 23/50
#  - 1s - loss: 0.3345 - acc: 0.9094 - val_loss: 0.3605 - val_acc: 0.9219
#
# Epoch 00023: val_loss did not improve from 0.29299
# Epoch 24/50
#  - 1s - loss: 0.3513 - acc: 0.9250 - val_loss: 0.3326 - val_acc: 0.9219
#
# Epoch 00024: val_loss did not improve from 0.29299
# Epoch 25/50
#  - 1s - loss: 0.3038 - acc: 0.9313 - val_loss: 0.4641 - val_acc: 0.8125
#
# Epoch 00025: val_loss did not improve from 0.29299
# Epoch 26/50
#  - 1s - loss: 0.2465 - acc: 0.9219 - val_loss: 0.5720 - val_acc: 0.7812
#
# Epoch 00026: val_loss did not improve from 0.29299
# Epoch 27/50
#  - 1s - loss: 0.3267 - acc: 0.9219 - val_loss: 0.4071 - val_acc: 0.8594
#
# Epoch 00027: val_loss did not improve from 0.29299
# Epoch 28/50
#  - 1s - loss: 0.3551 - acc: 0.8937 - val_loss: 0.3456 - val_acc: 0.9318
#
# Epoch 00028: val_loss did not improve from 0.29299
# Epoch 29/50
#  - 1s - loss: 0.2726 - acc: 0.9281 - val_loss: 0.3874 - val_acc: 0.8984
#
# Epoch 00029: val_loss did not improve from 0.29299
# Epoch 30/50
#  - 1s - loss: 0.2674 - acc: 0.9258 - val_loss: 0.4778 - val_acc: 0.8906
#
# Epoch 00030: val_loss did not improve from 0.29299
# Epoch 31/50
#  - 1s - loss: 0.3218 - acc: 0.9156 - val_loss: 0.2921 - val_acc: 0.9141
#
# Epoch 00031: val_loss improved from 0.29299 to 0.29208, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 32/50
#  - 1s - loss: 0.3647 - acc: 0.9281 - val_loss: 0.2674 - val_acc: 0.9375
#
# Epoch 00032: val_loss improved from 0.29208 to 0.26740, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_11.hdf5
# Epoch 33/50
#  - 1s - loss: 0.2719 - acc: 0.9313 - val_loss: 0.5082 - val_acc: 0.9062
#
# Epoch 00033: val_loss did not improve from 0.26740
# Epoch 34/50
#  - 1s - loss: 0.2650 - acc: 0.9188 - val_loss: 0.3068 - val_acc: 0.8516
#
# Epoch 00034: val_loss did not improve from 0.26740
# Epoch 35/50
#  - 1s - loss: 0.3789 - acc: 0.8844 - val_loss: 0.4763 - val_acc: 0.8516
#
# Epoch 00035: val_loss did not improve from 0.26740
# Epoch 36/50
#  - 1s - loss: 0.3851 - acc: 0.8812 - val_loss: 0.4962 - val_acc: 0.8594
#
# Epoch 00036: val_loss did not improve from 0.26740
# Epoch 37/50
#  - 1s - loss: 0.3200 - acc: 0.9469 - val_loss: 0.3516 - val_acc: 0.8906
#
# Epoch 00037: val_loss did not improve from 0.26740
# Epoch 38/50
#  - 1s - loss: 0.2752 - acc: 0.9281 - val_loss: 0.3901 - val_acc: 0.8594
#
# Epoch 00038: val_loss did not improve from 0.26740
# Epoch 39/50
#  - 1s - loss: 0.2524 - acc: 0.9344 - val_loss: 0.4847 - val_acc: 0.8516
#
# Epoch 00039: val_loss did not improve from 0.26740
# Epoch 40/50
#  - 1s - loss: 0.3448 - acc: 0.9000 - val_loss: 0.5171 - val_acc: 0.8594
#
# Epoch 00040: val_loss did not improve from 0.26740
# Epoch 41/50
#  - 1s - loss: 0.2183 - acc: 0.9531 - val_loss: 0.2943 - val_acc: 0.9062
#
# Epoch 00041: val_loss did not improve from 0.26740
# Epoch 42/50
#  - 1s - loss: 0.2694 - acc: 0.9281 - val_loss: 0.3856 - val_acc: 0.8828
#
# Epoch 00042: val_loss did not improve from 0.26740
# Epoch 43/50
#  - 1s - loss: 0.2758 - acc: 0.9219 - val_loss: 0.4958 - val_acc: 0.8594
#
# Epoch 00043: val_loss did not improve from 0.26740
# Epoch 44/50
#  - 1s - loss: 0.2681 - acc: 0.9344 - val_loss: 0.5256 - val_acc: 0.8594
#
# Epoch 00044: val_loss did not improve from 0.26740
# Epoch 45/50
#  - 1s - loss: 0.3049 - acc: 0.9250 - val_loss: 0.3569 - val_acc: 0.9205
#
# Epoch 00045: val_loss did not improve from 0.26740
# Epoch 46/50
#  - 1s - loss: 0.1842 - acc: 0.9750 - val_loss: 0.3293 - val_acc: 0.8594
#
# Epoch 00046: val_loss did not improve from 0.26740
# Epoch 47/50
#  - 1s - loss: 0.3197 - acc: 0.9031 - val_loss: 0.2702 - val_acc: 0.9297
#
# Epoch 00047: val_loss did not improve from 0.26740
# Epoch 48/50
#  - 1s - loss: 0.2337 - acc: 0.9500 - val_loss: 0.6122 - val_acc: 0.8438
#
# Epoch 00048: val_loss did not improve from 0.26740
# Epoch 49/50
#  - 1s - loss: 0.2250 - acc: 0.9188 - val_loss: 0.4375 - val_acc: 0.8438
#
# Epoch 00049: val_loss did not improve from 0.26740
# Epoch 50/50
#  - 1s - loss: 0.2884 - acc: 0.9094 - val_loss: 0.3065 - val_acc: 0.9141
#
# Epoch 00050: val_loss did not improve from 0.26740

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.214, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 12 tentativa - Test Precision: 19.64%, AUC: 0.317, Accuracy: 19.64%

# %% [markdown]
# Modelo adaptado do  **Lucas Valentim**
#
# *   Sem utilização das funções de regularização
# *   Função **SGD** para compilação
# *   Adicionado mais 2 camadas convolutivas

# %%
architecture = 'architecture_12'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu',input_shape=(None, None, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(96, (3, 3),activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(96, (3, 3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False), 
              loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 8s - loss: 3.2120 - acc: 0.5563 - val_loss: 0.7318 - val_acc: 0.5781
#
# Epoch 00001: val_loss improved from inf to 0.73184, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 2/50
#  - 1s - loss: 2.1640 - acc: 0.6219 - val_loss: 0.4666 - val_acc: 0.7969
#
# Epoch 00002: val_loss improved from 0.73184 to 0.46664, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 3/50
#  - 1s - loss: 1.9178 - acc: 0.5687 - val_loss: 0.7946 - val_acc: 0.7109
#
# Epoch 00003: val_loss did not improve from 0.46664
# Epoch 4/50
#  - 1s - loss: 1.0156 - acc: 0.7125 - val_loss: 0.9228 - val_acc: 0.7109
#
# Epoch 00004: val_loss did not improve from 0.46664
# Epoch 5/50
#  - 2s - loss: 0.5304 - acc: 0.7781 - val_loss: 1.1521 - val_acc: 0.7422
#
# Epoch 00005: val_loss did not improve from 0.46664
# Epoch 6/50
#  - 1s - loss: 0.4373 - acc: 0.8781 - val_loss: 0.4613 - val_acc: 0.8594
#
# Epoch 00006: val_loss improved from 0.46664 to 0.46127, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 7/50
#  - 1s - loss: 0.3259 - acc: 0.9177 - val_loss: 0.2825 - val_acc: 0.9297
#
# Epoch 00007: val_loss improved from 0.46127 to 0.28253, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 8/50
#  - 1s - loss: 0.3293 - acc: 0.8563 - val_loss: 0.3234 - val_acc: 0.9091
#
# Epoch 00008: val_loss did not improve from 0.28253
# Epoch 9/50
#  - 1s - loss: 0.4094 - acc: 0.8594 - val_loss: 0.6561 - val_acc: 0.7812
#
# Epoch 00009: val_loss did not improve from 0.28253
# Epoch 10/50
#  - 1s - loss: 0.3659 - acc: 0.8625 - val_loss: 0.3235 - val_acc: 0.9219
#
# Epoch 00010: val_loss did not improve from 0.28253
# Epoch 11/50
#  - 1s - loss: 0.2267 - acc: 0.9313 - val_loss: 0.5505 - val_acc: 0.8281
#
# Epoch 00011: val_loss did not improve from 0.28253
# Epoch 12/50
#  - 1s - loss: 0.2681 - acc: 0.9156 - val_loss: 0.6760 - val_acc: 0.8516
#
# Epoch 00012: val_loss did not improve from 0.28253
# Epoch 13/50
#  - 1s - loss: 0.3127 - acc: 0.9125 - val_loss: 0.4840 - val_acc: 0.8594
#
# Epoch 00013: val_loss did not improve from 0.28253
# Epoch 14/50
#  - 1s - loss: 0.3570 - acc: 0.8906 - val_loss: 0.3581 - val_acc: 0.8438
#
# Epoch 00014: val_loss did not improve from 0.28253
# Epoch 15/50
#  - 1s - loss: 0.2311 - acc: 0.9094 - val_loss: 0.4334 - val_acc: 0.8906
#
# Epoch 00015: val_loss did not improve from 0.28253
# Epoch 16/50
#  - 1s - loss: 0.1911 - acc: 0.9281 - val_loss: 0.1891 - val_acc: 0.9219
#
# Epoch 00016: val_loss improved from 0.28253 to 0.18909, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 17/50
#  - 1s - loss: 0.2831 - acc: 0.9125 - val_loss: 0.3778 - val_acc: 0.9141
#
# Epoch 00017: val_loss did not improve from 0.18909
# Epoch 18/50
#  - 1s - loss: 0.2416 - acc: 0.9094 - val_loss: 0.2471 - val_acc: 0.8906
#
# Epoch 00018: val_loss did not improve from 0.18909
# Epoch 19/50
#  - 1s - loss: 0.3532 - acc: 0.8844 - val_loss: 0.2279 - val_acc: 0.9219
#
# Epoch 00019: val_loss did not improve from 0.18909
# Epoch 20/50
#  - 1s - loss: 0.3233 - acc: 0.8719 - val_loss: 0.2152 - val_acc: 0.9453
#
# Epoch 00020: val_loss did not improve from 0.18909
# Epoch 21/50
#  - 1s - loss: 0.4304 - acc: 0.8625 - val_loss: 0.7818 - val_acc: 0.7891
#
# Epoch 00021: val_loss did not improve from 0.18909
# Epoch 22/50
#  - 1s - loss: 0.2507 - acc: 0.9344 - val_loss: 0.2688 - val_acc: 0.9375
#
# Epoch 00022: val_loss did not improve from 0.18909
# Epoch 23/50
#  - 1s - loss: 0.2819 - acc: 0.9219 - val_loss: 0.3536 - val_acc: 0.8750
#
# Epoch 00023: val_loss did not improve from 0.18909
# Epoch 24/50
#  - 1s - loss: 0.2009 - acc: 0.9375 - val_loss: 0.3372 - val_acc: 0.9297
#
# Epoch 00024: val_loss did not improve from 0.18909
# Epoch 25/50
#  - 1s - loss: 0.2456 - acc: 0.9125 - val_loss: 0.4291 - val_acc: 0.8182
#
# Epoch 00025: val_loss did not improve from 0.18909
# Epoch 26/50
#  - 1s - loss: 0.3618 - acc: 0.8688 - val_loss: 0.2373 - val_acc: 0.9219
#
# Epoch 00026: val_loss did not improve from 0.18909
# Epoch 27/50
#  - 1s - loss: 0.3015 - acc: 0.9000 - val_loss: 0.3057 - val_acc: 0.9141
#
# Epoch 00027: val_loss did not improve from 0.18909
# Epoch 28/50
#  - 1s - loss: 0.1947 - acc: 0.9344 - val_loss: 0.1853 - val_acc: 0.9453
#
# Epoch 00028: val_loss improved from 0.18909 to 0.18528, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 29/50
#  - 1s - loss: 0.2364 - acc: 0.9125 - val_loss: 0.2810 - val_acc: 0.9297
#
# Epoch 00029: val_loss did not improve from 0.18528
# Epoch 30/50
#  - 1s - loss: 0.2202 - acc: 0.9188 - val_loss: 0.3024 - val_acc: 0.8750
#
# Epoch 00030: val_loss did not improve from 0.18528
# Epoch 31/50
#  - 1s - loss: 0.2142 - acc: 0.9281 - val_loss: 0.3546 - val_acc: 0.8828
#
# Epoch 00031: val_loss did not improve from 0.18528
# Epoch 32/50
#  - 1s - loss: 0.3161 - acc: 0.9125 - val_loss: 0.4783 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.18528
# Epoch 33/50
#  - 1s - loss: 0.2716 - acc: 0.9387 - val_loss: 0.2114 - val_acc: 0.9375
#
# Epoch 00033: val_loss did not improve from 0.18528
# Epoch 34/50
#  - 1s - loss: 0.2222 - acc: 0.9313 - val_loss: 0.2711 - val_acc: 0.9062
#
# Epoch 00034: val_loss did not improve from 0.18528
# Epoch 35/50
#  - 1s - loss: 0.2113 - acc: 0.9094 - val_loss: 0.4897 - val_acc: 0.8594
#
# Epoch 00035: val_loss did not improve from 0.18528
# Epoch 36/50
#  - 1s - loss: 0.2000 - acc: 0.9500 - val_loss: 0.3828 - val_acc: 0.8906
#
# Epoch 00036: val_loss did not improve from 0.18528
# Epoch 37/50
#  - 1s - loss: 0.2716 - acc: 0.9031 - val_loss: 0.3901 - val_acc: 0.8281
#
# Epoch 00037: val_loss did not improve from 0.18528
# Epoch 38/50
#  - 1s - loss: 0.2277 - acc: 0.9062 - val_loss: 0.2614 - val_acc: 0.9141
#
# Epoch 00038: val_loss did not improve from 0.18528
# Epoch 39/50
#  - 1s - loss: 0.3393 - acc: 0.9031 - val_loss: 0.3252 - val_acc: 0.8828
#
# Epoch 00039: val_loss did not improve from 0.18528
# Epoch 40/50
#  - 1s - loss: 0.2369 - acc: 0.9375 - val_loss: 0.2864 - val_acc: 0.9062
#
# Epoch 00040: val_loss did not improve from 0.18528
# Epoch 41/50
#  - 1s - loss: 0.2312 - acc: 0.9125 - val_loss: 0.1025 - val_acc: 0.9844
#
# Epoch 00041: val_loss improved from 0.18528 to 0.10247, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_12.hdf5
# Epoch 42/50
#  - 1s - loss: 0.2109 - acc: 0.9313 - val_loss: 0.2862 - val_acc: 0.8906
#
# Epoch 00042: val_loss did not improve from 0.10247
# Epoch 43/50
#  - 1s - loss: 0.2552 - acc: 0.9062 - val_loss: 0.2741 - val_acc: 0.8750
#
# Epoch 00043: val_loss did not improve from 0.10247
# Epoch 44/50
#  - 1s - loss: 0.1381 - acc: 0.9531 - val_loss: 0.2392 - val_acc: 0.9219
#
# Epoch 00044: val_loss did not improve from 0.10247
# Epoch 45/50
#  - 1s - loss: 0.1697 - acc: 0.9406 - val_loss: 0.2674 - val_acc: 0.9375
#
# Epoch 00045: val_loss did not improve from 0.10247
# Epoch 46/50
#  - 1s - loss: 0.2151 - acc: 0.9250 - val_loss: 0.1905 - val_acc: 0.9141
#
# Epoch 00046: val_loss did not improve from 0.10247
# Epoch 47/50
#  - 1s - loss: 0.3778 - acc: 0.8781 - val_loss: 0.2182 - val_acc: 0.9531
#
# Epoch 00047: val_loss did not improve from 0.10247
# Epoch 48/50
#  - 1s - loss: 0.1309 - acc: 0.9469 - val_loss: 0.2097 - val_acc: 0.9453
#
# Epoch 00048: val_loss did not improve from 0.10247
# Epoch 49/50
#  - 1s - loss: 0.2926 - acc: 0.9031 - val_loss: 0.3127 - val_acc: 0.9141
#
# Epoch 00049: val_loss did not improve from 0.10247
# Epoch 50/50
#  - 1s - loss: 0.2572 - acc: 0.9125 - val_loss: 0.3598 - val_acc: 0.8438
#
# Epoch 00050: val_loss did not improve from 0.10247

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.317, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')

# %% [markdown]
# ## 13 tentativa - Test Precision: 19.64%, AUC: 0.537, Accuracy: 19.64

# %% [markdown]
# Modelo adaptado do **Lucas Valentim**
#
# *   Utilizado outra função de normalização, diferente da utilizada por ele.

# %%
architecture = 'architecture_13'

# %% [markdown]
# ### Modelo

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, BatchNormalization
from keras.regularizers import l2

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu',input_shape=(None, None, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(64, (5, 5), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(128, (7, 7),activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(128, (1,1)))
model.add(GlobalMaxPooling2D())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Treino

# %%
checkpointer = ModelCheckpoint(filepath='drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5', verbose=1, save_best_only=True)

# %%
training = model.fit_generator(train_batches, steps_per_epoch=stepsPerEpoche, 
                   validation_data=validation_batches, validation_steps=validationSteps,
                   epochs=50, verbose=2, callbacks=[checkpointer])
# Out:
# Epoch 1/50
#  - 9s - loss: 1.3127 - acc: 0.5750 - val_loss: 0.2486 - val_acc: 0.9375
#
# Epoch 00001: val_loss improved from inf to 0.24864, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_13.hdf5
# Epoch 2/50
#  - 0s - loss: 0.5498 - acc: 0.8000 - val_loss: 0.7190 - val_acc: 0.8516
#
# Epoch 00002: val_loss did not improve from 0.24864
# Epoch 3/50
#  - 0s - loss: 0.4569 - acc: 0.8594 - val_loss: 0.5751 - val_acc: 0.8594
#
# Epoch 00003: val_loss did not improve from 0.24864
# Epoch 4/50
#  - 1s - loss: 0.4161 - acc: 0.8656 - val_loss: 0.7934 - val_acc: 0.8203
#
# Epoch 00004: val_loss did not improve from 0.24864
# Epoch 5/50
#  - 1s - loss: 0.2798 - acc: 0.9031 - val_loss: 0.4965 - val_acc: 0.8864
#
# Epoch 00005: val_loss did not improve from 0.24864
# Epoch 6/50
#  - 1s - loss: 0.2654 - acc: 0.8969 - val_loss: 0.1612 - val_acc: 0.9453
#
# Epoch 00006: val_loss improved from 0.24864 to 0.16120, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_13.hdf5
# Epoch 7/50
#  - 1s - loss: 0.2149 - acc: 0.9094 - val_loss: 0.6160 - val_acc: 0.8906
#
# Epoch 00007: val_loss did not improve from 0.16120
# Epoch 8/50
#  - 1s - loss: 0.3339 - acc: 0.9250 - val_loss: 0.3015 - val_acc: 0.8906
#
# Epoch 00008: val_loss did not improve from 0.16120
# Epoch 9/50
#  - 1s - loss: 0.3233 - acc: 0.8937 - val_loss: 0.1893 - val_acc: 0.9453
#
# Epoch 00009: val_loss did not improve from 0.16120
# Epoch 10/50
#  - 1s - loss: 0.1936 - acc: 0.9419 - val_loss: 0.7043 - val_acc: 0.7500
#
# Epoch 00010: val_loss did not improve from 0.16120
# Epoch 11/50
#  - 1s - loss: 0.1747 - acc: 0.9500 - val_loss: 0.2008 - val_acc: 0.9453
#
# Epoch 00011: val_loss did not improve from 0.16120
# Epoch 12/50
#  - 1s - loss: 0.1381 - acc: 0.9500 - val_loss: 0.5174 - val_acc: 0.8750
#
# Epoch 00012: val_loss did not improve from 0.16120
# Epoch 13/50
#  - 1s - loss: 0.1560 - acc: 0.9375 - val_loss: 0.4172 - val_acc: 0.9062
#
# Epoch 00013: val_loss did not improve from 0.16120
# Epoch 14/50
#  - 1s - loss: 0.2625 - acc: 0.9062 - val_loss: 0.4336 - val_acc: 0.8672
#
# Epoch 00014: val_loss did not improve from 0.16120
# Epoch 15/50
#  - 1s - loss: 0.3026 - acc: 0.9125 - val_loss: 0.4415 - val_acc: 0.8906
#
# Epoch 00015: val_loss did not improve from 0.16120
# Epoch 16/50
#  - 1s - loss: 0.2266 - acc: 0.9156 - val_loss: 0.3129 - val_acc: 0.8828
#
# Epoch 00016: val_loss did not improve from 0.16120
# Epoch 17/50
#  - 1s - loss: 0.1532 - acc: 0.9344 - val_loss: 0.2062 - val_acc: 0.9453
#
# Epoch 00017: val_loss did not improve from 0.16120
# Epoch 18/50
#  - 1s - loss: 0.2642 - acc: 0.9031 - val_loss: 0.2205 - val_acc: 0.9375
#
# Epoch 00018: val_loss did not improve from 0.16120
# Epoch 19/50
#  - 1s - loss: 0.2570 - acc: 0.9188 - val_loss: 0.3064 - val_acc: 0.8594
#
# Epoch 00019: val_loss did not improve from 0.16120
# Epoch 20/50
#  - 1s - loss: 0.1841 - acc: 0.9281 - val_loss: 0.6217 - val_acc: 0.8047
#
# Epoch 00020: val_loss did not improve from 0.16120
# Epoch 21/50
#  - 1s - loss: 0.1980 - acc: 0.9281 - val_loss: 0.3093 - val_acc: 0.8750
#
# Epoch 00021: val_loss did not improve from 0.16120
# Epoch 22/50
#  - 1s - loss: 0.3143 - acc: 0.9125 - val_loss: 0.3485 - val_acc: 0.9375
#
# Epoch 00022: val_loss did not improve from 0.16120
# Epoch 23/50
#  - 1s - loss: 0.1781 - acc: 0.9437 - val_loss: 0.2023 - val_acc: 0.9318
#
# Epoch 00023: val_loss did not improve from 0.16120
# Epoch 24/50
#  - 1s - loss: 0.2321 - acc: 0.9313 - val_loss: 0.7792 - val_acc: 0.7422
#
# Epoch 00024: val_loss did not improve from 0.16120
# Epoch 25/50
#  - 1s - loss: 0.2136 - acc: 0.9344 - val_loss: 1.0154 - val_acc: 0.5781
#
# Epoch 00025: val_loss did not improve from 0.16120
# Epoch 26/50
#  - 1s - loss: 0.1993 - acc: 0.9375 - val_loss: 1.4105 - val_acc: 0.4609
#
# Epoch 00026: val_loss did not improve from 0.16120
# Epoch 27/50
#  - 1s - loss: 0.2065 - acc: 0.9250 - val_loss: 0.5017 - val_acc: 0.8047
#
# Epoch 00027: val_loss did not improve from 0.16120
# Epoch 28/50
#  - 1s - loss: 0.2408 - acc: 0.9188 - val_loss: 0.3174 - val_acc: 0.8906
#
# Epoch 00028: val_loss did not improve from 0.16120
# Epoch 29/50
#  - 1s - loss: 0.2640 - acc: 0.9188 - val_loss: 0.7740 - val_acc: 0.7188
#
# Epoch 00029: val_loss did not improve from 0.16120
# Epoch 30/50
#  - 1s - loss: 0.2596 - acc: 0.8969 - val_loss: 0.5660 - val_acc: 0.7891
#
# Epoch 00030: val_loss did not improve from 0.16120
# Epoch 31/50
#  - 1s - loss: 0.1843 - acc: 0.9562 - val_loss: 0.2811 - val_acc: 0.9219
#
# Epoch 00031: val_loss did not improve from 0.16120
# Epoch 32/50
#  - 1s - loss: 0.1713 - acc: 0.9219 - val_loss: 0.4047 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.16120
# Epoch 33/50
#  - 1s - loss: 0.3447 - acc: 0.9125 - val_loss: 0.6805 - val_acc: 0.8203
#
# Epoch 00033: val_loss did not improve from 0.16120
# Epoch 34/50
#  - 1s - loss: 0.2068 - acc: 0.9375 - val_loss: 0.1091 - val_acc: 0.9531
#
# Epoch 00034: val_loss improved from 0.16120 to 0.10913, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_13.hdf5
# Epoch 35/50
#  - 1s - loss: 0.1775 - acc: 0.9344 - val_loss: 0.2498 - val_acc: 0.9375
#
# Epoch 00035: val_loss did not improve from 0.10913
# Epoch 36/50
#  - 1s - loss: 0.2363 - acc: 0.9065 - val_loss: 0.2867 - val_acc: 0.9062
#
# Epoch 00036: val_loss did not improve from 0.10913
# Epoch 37/50
#  - 1s - loss: 0.2337 - acc: 0.9219 - val_loss: 0.4635 - val_acc: 0.8125
#
# Epoch 00037: val_loss did not improve from 0.10913
# Epoch 38/50
#  - 1s - loss: 0.2155 - acc: 0.9281 - val_loss: 0.2744 - val_acc: 0.8672
#
# Epoch 00038: val_loss did not improve from 0.10913
# Epoch 39/50
#  - 1s - loss: 0.2356 - acc: 0.9250 - val_loss: 0.3725 - val_acc: 0.8594
#
# Epoch 00039: val_loss did not improve from 0.10913
# Epoch 40/50
#  - 1s - loss: 0.2327 - acc: 0.8969 - val_loss: 0.2634 - val_acc: 0.8523
#
# Epoch 00040: val_loss did not improve from 0.10913
# Epoch 41/50
#  - 1s - loss: 0.1787 - acc: 0.9437 - val_loss: 0.4272 - val_acc: 0.7891
#
# Epoch 00041: val_loss did not improve from 0.10913
# Epoch 42/50
#  - 1s - loss: 0.2992 - acc: 0.8906 - val_loss: 0.3852 - val_acc: 0.8281
#
# Epoch 00042: val_loss did not improve from 0.10913
# Epoch 43/50
#  - 1s - loss: 0.2464 - acc: 0.9344 - val_loss: 0.4900 - val_acc: 0.7969
#
# Epoch 00043: val_loss did not improve from 0.10913
# Epoch 44/50
#  - 1s - loss: 0.1864 - acc: 0.9406 - val_loss: 0.1913 - val_acc: 0.9531
#
# Epoch 00044: val_loss did not improve from 0.10913
# Epoch 45/50
#  - 1s - loss: 0.2091 - acc: 0.9219 - val_loss: 0.1562 - val_acc: 0.9375
#
# Epoch 00045: val_loss did not improve from 0.10913
# Epoch 46/50
#  - 1s - loss: 0.1727 - acc: 0.9344 - val_loss: 0.6292 - val_acc: 0.7891
#
# Epoch 00046: val_loss did not improve from 0.10913
# Epoch 47/50
#  - 1s - loss: 0.1619 - acc: 0.9594 - val_loss: 0.6420 - val_acc: 0.7656
#
# Epoch 00047: val_loss did not improve from 0.10913
# Epoch 48/50
#  - 1s - loss: 0.2223 - acc: 0.9250 - val_loss: 0.3131 - val_acc: 0.9219
#
# Epoch 00048: val_loss did not improve from 0.10913
# Epoch 49/50
#  - 1s - loss: 0.2085 - acc: 0.9406 - val_loss: 0.0701 - val_acc: 0.9844
#
# Epoch 00049: val_loss improved from 0.10913 to 0.07008, saving model to drive/My Drive/Resultado/Segmentado/weights_architecture_13.hdf5
# Epoch 50/50
#  - 1s - loss: 0.1676 - acc: 0.9562 - val_loss: 0.3705 - val_acc: 0.8906
#
# Epoch 00050: val_loss did not improve from 0.07008

# %%
model.load_weights('drive/My Drive/Resultado/Segmentado/weights_' + architecture + '.hdf5')

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), training.history["loss"], label="train_loss" )
plt.plot(np.arange(0, 50), training.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 50), training.history["acc" ], label="train_acc" )
plt.plot(np.arange(0, 50), training.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.savefig('drive/My Drive/Resultado/Segmentado/Treino-' + architecture + '.png', 
            bbox_inches='tight')

# %% [markdown]
# ### Teste

# %% [markdown]
# *   [How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/)
# *   [Classification: ROC and AUC ](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc)
# *   [sklearn.metrics.roc_curve](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html)
# *   [sklearn.metrics.accuracy_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score)

# %%
y_true, y_predict, prob = ler_images_teste(architecture)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
results[architecture] = [precision_score(y_true, y_predict, average='binary'),
                         roc_auc_score(y_true, prob),
                         accuracy_score(y_true, y_predict)]
print('Test Precision: {:.2f}%, AUC: {:.3f}, Accuracy: {:.2f}%'
      .format(100 * results[architecture][0], 
              results[architecture][1],
              100 * results[architecture][2]))
# Out:
# Test Precision: 19.64%, AUC: 0.537, Accuracy: 19.64%

# %%
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_true, prob)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.ylabel('TPR')
plt.xlabel('FPR')
plt.plot(fpr, tpr, marker='.')
plt.savefig('drive/My Drive/Resultado/Segmentado/Teste-ROC_CURVE-' + architecture + '.png', bbox_inches='tight')
